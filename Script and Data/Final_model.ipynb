# %%
import numpy as np
import pandas as pd
import math
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statistics as st
from math import *
from sklearn.preprocessing import MinMaxScaler # Normalization
from sklearn.linear_model import LinearRegression # Regression linear model
from sklearn.model_selection import train_test_split # Splitting the data set
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score # Metrics for errors
from sklearn.model_selection import KFold # Cross validation
from tqdm import tqdm
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sklearn import metrics
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import tensorflow as tf

filepath = ""

# %% [markdown]
# Download dataset

# %%
btc = pd.read_csv(filepath + "BTC-USD.csv")
btc.head(2)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1  2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
#
#      Volume
# 0  21056800
# 1  34483200

# %%
btc.shape
# Out:
# (2771, 7)

# %% [markdown]
# EDA

# %%
plt.figure(figsize = (18,9))
plt.plot(range(btc.shape[0]),(btc['Low']+btc['High'])/2.0)
plt.xticks(range(0,btc.shape[0],500),btc['Date'].loc[::500],rotation=45)
plt.xlabel('Date',fontsize=18)
plt.ylabel('Mid Price',fontsize=18)
plt.show()

# %% [markdown]
# Creation of new variables

# %%
#NEW BITCOIN VARIABLES
#btc["Mid"] = (btc["Open"] + btc["Low"]) / 2 #Mid price
#btc['SMA_7_Price'] = btc.iloc[:,1].rolling(window=7).mean() 
#btc['SMA_14_Price'] = btc.iloc[:,1].rolling(window=14).mean()
#btc['SMA_21_Price'] = btc.iloc[:,1].rolling(window=21).mean()
#btc['SMA_7_Volume'] = btc["Volume"].rolling(window=7).mean() 
#btc['SMA_14_Volume'] = btc["Volume"].rolling(window=14).mean()
#btc['SMA_21_Volume'] = btc["Volume"].rolling(window=21).mean()

btc["_1_Day_Vol"] = btc['Volume'].shift(periods = 1) #Volume of the day before
btc["_1_Day_Vol_Diff"] = btc["Volume"] - btc["_1_Day_Vol"] #Difference between the price T-1 and T0
btc["_1_Day_Vol_Diff_Percent"] = btc["_1_Day_Vol_Diff"] / btc["_1_Day_Vol"] #Difference between the Volume T-1 and T0 in Percent
btc['SMA_7_Volume'] = btc["_1_Day_Vol_Diff_Percent"].rolling(window=7).mean() 
btc['SMA_14_Volume'] = btc["_1_Day_Vol_Diff_Percent"].rolling(window=14).mean()
btc['SMA_21_Volume'] = btc["_1_Day_Vol_Diff_Percent"].rolling(window=21).mean()


    #Price
btc["1_Day_Price"] = btc['Close'].shift(periods = -1) #Price of the day after
btc["1_Day_Price_Diff"] = btc ["1_Day_Price"] - btc["Close"] #Difference between the price T0 and T1
btc["1_Day_Price_Diff_Percent"] = btc["1_Day_Price_Diff"] / btc ["Close"] #Difference between the price T0 and T1 in Percent

btc["_1_Day_Price"] = btc['Close'].shift(periods = 1) #Price of the day before
btc["_1_Day_Price_Diff"] = btc["Close"] - btc ["_1_Day_Price"] #Difference between the price T-1 and T0
btc["_1_Day_Price_Diff_Percent"] = btc["_1_Day_Price_Diff"] / btc ["_1_Day_Price"] #Difference between the price T-1 and T0 in Percent
btc['SMA_7_Price'] = btc["_1_Day_Price_Diff_Percent"].rolling(window=7).mean() 
btc['SMA_14_Price'] = btc["_1_Day_Price_Diff_Percent"].rolling(window=14).mean()
btc['SMA_21_Price'] = btc["_1_Day_Price_Diff_Percent"].rolling(window=21).mean()

for i in range(1,15):
    btc["Vol",i] = btc['_1_Day_Vol_Diff_Percent'].shift(periods = i) #old volume on 14 days
for i in range(1,15):
    btc["Price",i] = btc['_1_Day_Price_Diff_Percent'].shift(periods = i) #old price on 14 days

# %%
plt.hist(btc["1_Day_Price_Diff_Percent"], bins = "auto")
print(btc["1_Day_Price_Diff_Percent"].mean())
print(btc["1_Day_Price_Diff_Percent"].std())
# Out:
# 0.0023670062935205217
# 0.038763827030897514

# %%
sns.boxplot(x = btc["1_Day_Price_Diff_Percent"])
# Out:
# <AxesSubplot:xlabel='1_Day_Price_Diff_Percent'>

# %%
#histogram
btc.hist(bins=30, figsize=(30, 20))
# Out:
# array([[<AxesSubplot:title={'center':'Open'}>,
#         <AxesSubplot:title={'center':'High'}>,
#         <AxesSubplot:title={'center':'Low'}>,
#         <AxesSubplot:title={'center':'Close'}>,
#         <AxesSubplot:title={'center':'Adj Close'}>,
#         <AxesSubplot:title={'center':'Volume'}>,
#         <AxesSubplot:title={'center':'_1_Day_Vol'}>],
#        [<AxesSubplot:title={'center':'_1_Day_Vol_Diff'}>,
#         <AxesSubplot:title={'center':'_1_Day_Vol_Diff_Percent'}>,
#         <AxesSubplot:title={'center':'SMA_7_Volume'}>,
#         <AxesSubplot:title={'center':'SMA_14_Volume'}>,
#         <AxesSubplot:title={'center':'SMA_21_Volume'}>,
#         <AxesSubplot:title={'center':'1_Day_Price'}>,
#         <AxesSubplot:title={'center':'1_Day_Price_Diff'}>],
#        [<AxesSubplot:title={'center':'1_Day_Price_Diff_Percent'}>,
#         <AxesSubplot:title={'center':'_1_Day_Price'}>,
#         <AxesSubplot:title={'center':'_1_Day_Price_Diff'}>,
#         <AxesSubplot:title={'center':'_1_Day_Price_Diff_Percent'}>,
#         <AxesSubplot:title={'center':'SMA_7_Price'}>,
#         <AxesSubplot:title={'center':'SMA_14_Price'}>,
#         <AxesSubplot:title={'center':'SMA_21_Price'}>],
#        [<AxesSubplot:title={'center':"('Vol', 1)"}>,
#         <AxesSubplot:title={'center':"('Vol', 2)"}>,
#         <AxesSubplot:title={'center':"('Vol', 3)"}>,
#         <AxesSubplot:title={'center':"('Vol', 4)"}>,
#         <AxesSubplot:title={'center':"('Vol', 5)"}>,
#         <AxesSubplot:title={'center':"('Vol', 6)"}>,
#         <AxesSubplot:title={'center':"('Vol', 7)"}>],
#        [<AxesSubplot:title={'center':"('Vol', 8)"}>,
#         <AxesSubplot:title={'center':"('Vol', 9)"}>,
#         <AxesSubplot:title={'center':"('Vol', 10)"}>,
#         <AxesSubplot:title={'center':"('Vol', 11)"}>,
#         <AxesSubplot:title={'center':"('Vol', 12)"}>,
#         <AxesSubplot:title={'center':"('Vol', 13)"}>,
#         <AxesSubplot:title={'center':"('Vol', 14)"}>],
#        [<AxesSubplot:title={'center':"('Price', 1)"}>,
#         <AxesSubplot:title={'center':"('Price', 2)"}>,
#         <AxesSubplot:title={'center':"('Price', 3)"}>,
#         <AxesSubplot:title={'center':"('Price', 4)"}>,
#         <AxesSubplot:title={'center':"('Price', 5)"}>,
#         <AxesSubplot:title={'center':"('Price', 6)"}>,
#         <AxesSubplot:title={'center':"('Price', 7)"}>],
#        [<AxesSubplot:title={'center':"('Price', 8)"}>,
#         <AxesSubplot:title={'center':"('Price', 9)"}>,
#         <AxesSubplot:title={'center':"('Price', 10)"}>,
#         <AxesSubplot:title={'center':"('Price', 11)"}>,
#         <AxesSubplot:title={'center':"('Price', 12)"}>,
#         <AxesSubplot:title={'center':"('Price', 13)"}>,
#         <AxesSubplot:title={'center':"('Price', 14)"}>]], dtype=object)

# %% [markdown]
# Naive Model

# %%
def rmse_(y_true, y_pred):
    MSE = np.square(np.subtract(y_true,y_pred)).mean() 
    RMSE = math.sqrt(MSE)
    print("RMSE :" , RMSE)

# %%
rmse_(btc["1_Day_Price_Diff_Percent"][1500:1875], btc["_1_Day_Price_Diff_Percent"][1500:1875])
# Out:
# RMSE : 0.05554763910128054

# %%
#rmse_(btc["1_Day_Price"][1500:1875], btc["Close"][1500:1875])

# %% [markdown]
# Pred = 0

# %%
math.sqrt(btc["1_Day_Price_Diff_Percent"][1500:1875].mean())
# Out:
# 0.04149486771590367

# %%
from matplotlib.pyplot import figure

figure(figsize=(20,8), dpi=80)

l = []
for i in range(1500,1875):
    l.append(i)
l

plt.plot(l, btc["1_Day_Price_Diff_Percent"][1500:1875].values, label = "Real")
plt.plot(l, btc["_1_Day_Price_Diff_Percent"][1500:1875], label = "Pred")

plt.xlabel('Day')
# naming the y axis
plt.ylabel('Daily price difference in percent')
# giving a title to my graph
plt.title('Naive Model')
  
# show a legend on the plot
plt.legend()
  
# function to show the plot
plt.show()

# %%
from matplotlib.pyplot import figure

figure(figsize=(20,8), dpi=80)

l = []
for i in range(1500,1875):
    l.append(i)
l

plt.plot(l, btc["1_Day_Price"][1500:1875].values, label = "Real")
plt.plot(l, btc["Close"][1500:1875], label = "Pred")

plt.xlabel('Day')
# naming the y axis
plt.ylabel('Price in Us Dollar')
# giving a title to my graph
plt.title('Naive Model')
  
# show a legend on the plot
plt.legend()
  
# function to show the plot
plt.show()

# %% [markdown]
# DNN Model

# %%
import numpy as np
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, LSTM, Bidirectional
from keras.datasets import imdb

# %%
#error is normal
# %load_ext tensorboard
import tensorflow as tf
import datetime, os
logs_base_dir = "./logs"
os.makedirs(logs_base_dir, exist_ok=True)
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
no_features = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', '1_Day_Price', '1_Day_Price_Diff', '1_Day_Price_Diff_Percent','_1_Day_Price', '_1_Day_Price_Diff', '_1_Day_Vol', '_1_Day_Vol_Diff']
x_train = btc.drop(no_features, 1)


import random
random.seed(2022)
tf.random.set_seed(2022)
initializer = tf.keras.initializers.HeNormal(seed=2022)
def pythonash_model():
    inputs_ = tf.keras.Input(shape = [x_train.shape[1]])
    x = tf.keras.layers.Dense(32, kernel_initializer = initializer)(inputs_)
    batch = tf.keras.layers.BatchNormalization()(x)
    leaky = tf.keras.layers.LeakyReLU(0.1)(batch)
    
    x = tf.keras.layers.Dense(32, kernel_initializer = initializer)(leaky)
    batch = tf.keras.layers.BatchNormalization()(x)
    leaky = tf.keras.layers.LeakyReLU(0.1)(batch)
    
    x = tf.keras.layers.Dense(64, kernel_initializer = initializer)(leaky)
    batch = tf.keras.layers.BatchNormalization()(x)
    leaky = tf.keras.layers.LeakyReLU(0.1)(batch)

    x = tf.keras.layers.Dense(64, kernel_initializer = initializer)(leaky)
    batch = tf.keras.layers.BatchNormalization()(x)
    leaky = tf.keras.layers.LeakyReLU(0.1)(batch)
    
    x = tf.keras.layers.Dense(32, kernel_initializer = initializer)(leaky)
    batch = tf.keras.layers.BatchNormalization()(x)
    leaky = tf.keras.layers.LeakyReLU(0.1)(batch)
    drop = tf.keras.layers.Dropout(0.1)(leaky) #Dropout to avoid overfitting
    
    x = tf.keras.layers.Dense(32, kernel_initializer = initializer)(leaky)
    batch = tf.keras.layers.BatchNormalization()(x)
    leaky = tf.keras.layers.LeakyReLU(0.1)(batch)
    
    x = tf.keras.layers.Dense(16, kernel_initializer = initializer)(leaky)
    batch = tf.keras.layers.BatchNormalization()(x)
    leaky = tf.keras.layers.LeakyReLU(0.1)(batch)
    drop = tf.keras.layers.Dropout(0.1)(leaky) #Dropout to avoid overfitting
    
    x = tf.keras.layers.Dense(8, kernel_initializer = initializer)(leaky)
    batch = tf.keras.layers.BatchNormalization()(x)
    leaky = tf.keras.layers.LeakyReLU(0.1)(batch)
    drop = tf.keras.layers.Dropout(0.1)(leaky) #Dropout to avoid overfitting
    
    outputs_ = tf.keras.layers.Dense(1)(drop)
    
    model = tf.keras.Model(inputs = inputs_, outputs = outputs_)
    
    rmse = tf.keras.metrics.RootMeanSquaredError()

    learning_sch = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate = 0.0015,
    decay_steps = 1500,
    decay_rate = 0.95)
    adam = tf.keras.optimizers.Adam(learning_rate = learning_sch)
    
    model.compile(loss = 'mse', metrics = [rmse,], optimizer = adam) #adam optimizer!!
    return model

#pythonash_model().summary()

# %%
import graphviz
import pydot
tf.keras.utils.plot_model(pythonash_model(),show_shapes=True,expand_nested=True)

#already intsall ... cound't fix the issue
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
df_x = btc.drop(no_features, axis=1)[25:1500]
df_y = btc["1_Day_Price_Diff_Percent"][25:1500]

test_x = btc.drop(no_features, axis=1)[1500:1875]
test_y = btc["1_Day_Price_Diff_Percent"][1500:1875]

# %%
kfold_generator = KFold(n_splits =10, shuffle=True, random_state = 2000)
kfold_generator
# Out:
# KFold(n_splits=10, random_state=2000, shuffle=True)

# %%
#Final model
# WModel save
from datetime import datetime
#callbacks = tf.keras.callbacks.ModelCheckpoint(filepath + "M1", save_best_only = True)
for train_index, val_index in kfold_generator.split(df_x, df_y):
    # Split training dataset.
    train_x, train_y = df_x.iloc[train_index], df_y.iloc[train_index]
    # Split validation dataset.
    val_x, val_y = df_x.iloc[val_index], df_y.iloc[val_index]
    # Make tensor dataset.
    ##tf_train = tf.data.Dataset.from_tensor_slices((train_x, train_y)).shuffle(2022).batch(500, drop_remainder=True).prefetch(1)
    ##tf_val = tf.data.Dataset.from_tensor_slices((val_x, val_y)).shuffle(2022).batch(1024, drop_remainder=True).prefetch(1)
    # Load model
    model = pythonash_model()
    # Model fitting
    logdir = os.path.join(logs_base_dir, datetime.now().strftime("%Y%m%d-%H%M%S"))
    tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=25)
    
    model1 = model.fit(train_x, train_y, batch_size=64, epochs = 25, ### change the epochs into more numbers.
             validation_data = (val_x, val_y), shuffle=True, callbacks=[tensorboard_callback])
    # Delete tensor dataset and model to save memory
    del model
    ##del tf_train
    ##del tf_val
    
    
#best_model = tf.keras.models.load_model(filepath + "M1")   
#pred1 = best_model.predict(test_x)
# Out:
# Epoch 1/25
# 21/21 [==============================] - 3s 37ms/step - loss: 0.3519 - root_mean_squared_error: 0.5932 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0713
# Epoch 2/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1085 - root_mean_squared_error: 0.3293 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0752
# Epoch 3/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0479 - root_mean_squared_error: 0.2188 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1018
# Epoch 4/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0317 - root_mean_squared_error: 0.1780 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1075
# Epoch 5/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0274 - root_mean_squared_error: 0.1654 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0896
# Epoch 6/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0222 - root_mean_squared_error: 0.1489 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0836
# Epoch 7/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0201 - root_mean_squared_error: 0.1418 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0681
# Epoch 8/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0155 - root_mean_squared_error: 0.1246 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0622
# Epoch 9/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0148 - root_mean_squared_error: 0.1218 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0618
# Epoch 10/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1191 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0603
# Epoch 11/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0133 - root_mean_squared_error: 0.1155 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0583
# Epoch 12/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0126 - root_mean_squared_error: 0.1124 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0597
# Epoch 13/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0098 - root_mean_squared_error: 0.0991 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0577
# Epoch 14/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0099 - root_mean_squared_error: 0.0995 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0587
# Epoch 15/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0101 - root_mean_squared_error: 0.1003 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0583
# Epoch 16/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0082 - root_mean_squared_error: 0.0904 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0575
# Epoch 17/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0089 - root_mean_squared_error: 0.0946 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0573
# Epoch 18/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0085 - root_mean_squared_error: 0.0924 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0578
# Epoch 19/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0087 - root_mean_squared_error: 0.0935 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0569
# Epoch 20/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0077 - root_mean_squared_error: 0.0877 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0555
# Epoch 21/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0070 - root_mean_squared_error: 0.0837 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0544
# Epoch 22/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0062 - root_mean_squared_error: 0.0786 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0541
# Epoch 23/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0062 - root_mean_squared_error: 0.0789 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0530
# Epoch 24/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0062 - root_mean_squared_error: 0.0785 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0514
# Epoch 25/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0064 - root_mean_squared_error: 0.0798 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0509
# Epoch 1/25
# 21/21 [==============================] - 2s 29ms/step - loss: 1.0688 - root_mean_squared_error: 1.0338 - val_loss: 0.0569 - val_root_mean_squared_error: 0.2385
# Epoch 2/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4242 - root_mean_squared_error: 0.6513 - val_loss: 0.0264 - val_root_mean_squared_error: 0.1626
# Epoch 3/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2372 - root_mean_squared_error: 0.4871 - val_loss: 0.0390 - val_root_mean_squared_error: 0.1975
# Epoch 4/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1796 - root_mean_squared_error: 0.4238 - val_loss: 0.0431 - val_root_mean_squared_error: 0.2077
# Epoch 5/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1462 - root_mean_squared_error: 0.3824 - val_loss: 0.0399 - val_root_mean_squared_error: 0.1998
# Epoch 6/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.1200 - root_mean_squared_error: 0.3464 - val_loss: 0.0299 - val_root_mean_squared_error: 0.1730
# Epoch 7/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1048 - root_mean_squared_error: 0.3237 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1514
# Epoch 8/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0979 - root_mean_squared_error: 0.3129 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1456
# Epoch 9/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0770 - root_mean_squared_error: 0.2776 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1434
# Epoch 10/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0676 - root_mean_squared_error: 0.2600 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1311
# Epoch 11/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0668 - root_mean_squared_error: 0.2584 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1251
# Epoch 12/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0648 - root_mean_squared_error: 0.2545 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1172
# Epoch 13/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0535 - root_mean_squared_error: 0.2312 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1198
# Epoch 14/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0625 - root_mean_squared_error: 0.2500 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1081
# Epoch 15/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0591 - root_mean_squared_error: 0.2431 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0941
# Epoch 16/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0409 - root_mean_squared_error: 0.2022 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0939
# Epoch 17/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0425 - root_mean_squared_error: 0.2062 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0968
# Epoch 18/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0369 - root_mean_squared_error: 0.1922 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0933
# Epoch 19/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0313 - root_mean_squared_error: 0.1770 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0929
# Epoch 20/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0319 - root_mean_squared_error: 0.1785 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0820
# Epoch 21/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0273 - root_mean_squared_error: 0.1651 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0813
# Epoch 22/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0228 - root_mean_squared_error: 0.1509 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0820
# Epoch 23/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0239 - root_mean_squared_error: 0.1546 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0770
# Epoch 24/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0242 - root_mean_squared_error: 0.1557 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0705
# Epoch 25/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0218 - root_mean_squared_error: 0.1475 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0696
# Epoch 1/25
# 21/21 [==============================] - 3s 26ms/step - loss: 0.3724 - root_mean_squared_error: 0.6102 - val_loss: 0.0500 - val_root_mean_squared_error: 0.2237
# Epoch 2/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1388 - root_mean_squared_error: 0.3726 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1260
# Epoch 3/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1002 - root_mean_squared_error: 0.3166 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1080
# Epoch 4/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0917 - root_mean_squared_error: 0.3029 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1146
# Epoch 5/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0794 - root_mean_squared_error: 0.2819 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0958
# Epoch 6/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0898 - root_mean_squared_error: 0.2997 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0890
# Epoch 7/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0589 - root_mean_squared_error: 0.2427 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0936
# Epoch 8/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0541 - root_mean_squared_error: 0.2327 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0834
# Epoch 9/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0663 - root_mean_squared_error: 0.2575 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0907
# Epoch 10/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0429 - root_mean_squared_error: 0.2072 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0865
# Epoch 11/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0389 - root_mean_squared_error: 0.1971 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0928
# Epoch 12/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0340 - root_mean_squared_error: 0.1845 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0850
# Epoch 13/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0437 - root_mean_squared_error: 0.2089 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0808
# Epoch 14/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0432 - root_mean_squared_error: 0.2079 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0750
# Epoch 15/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0368 - root_mean_squared_error: 0.1919 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0819
# Epoch 16/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0330 - root_mean_squared_error: 0.1817 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0751
# Epoch 17/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0268 - root_mean_squared_error: 0.1637 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0689
# Epoch 18/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0314 - root_mean_squared_error: 0.1772 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0550
# Epoch 19/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0216 - root_mean_squared_error: 0.1470 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0546
# Epoch 20/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0289 - root_mean_squared_error: 0.1700 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0505
# Epoch 21/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0195 - root_mean_squared_error: 0.1395 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0498
# Epoch 22/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0128 - root_mean_squared_error: 0.1131 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0491
# Epoch 23/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0151 - root_mean_squared_error: 0.1229 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0483
# Epoch 24/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0205 - root_mean_squared_error: 0.1431 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0484
# Epoch 25/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0126 - root_mean_squared_error: 0.1123 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0458
# Epoch 1/25
# 21/21 [==============================] - 3s 30ms/step - loss: 0.2814 - root_mean_squared_error: 0.5304 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0964
# Epoch 2/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0919 - root_mean_squared_error: 0.3031 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1208
# Epoch 3/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0551 - root_mean_squared_error: 0.2346 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1116
# Epoch 4/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0428 - root_mean_squared_error: 0.2068 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1005
# Epoch 5/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0447 - root_mean_squared_error: 0.2114 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0901
# Epoch 6/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0291 - root_mean_squared_error: 0.1705 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0834
# Epoch 7/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0254 - root_mean_squared_error: 0.1594 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0783
# Epoch 8/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0200 - root_mean_squared_error: 0.1414 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0719
# Epoch 9/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0208 - root_mean_squared_error: 0.1443 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0722
# Epoch 10/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0164 - root_mean_squared_error: 0.1282 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0691
# Epoch 11/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0168 - root_mean_squared_error: 0.1294 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0712
# Epoch 12/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0162 - root_mean_squared_error: 0.1272 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0726
# Epoch 13/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0144 - root_mean_squared_error: 0.1200 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0662
# Epoch 14/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0138 - root_mean_squared_error: 0.1175 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0638
# Epoch 15/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0122 - root_mean_squared_error: 0.1103 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0645
# Epoch 16/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0109 - root_mean_squared_error: 0.1044 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0645
# Epoch 17/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0088 - root_mean_squared_error: 0.0941 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613
# Epoch 18/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0084 - root_mean_squared_error: 0.0914 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0596
# Epoch 19/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0084 - root_mean_squared_error: 0.0915 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0576
# Epoch 20/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0075 - root_mean_squared_error: 0.0869 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0565
# Epoch 21/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0070 - root_mean_squared_error: 0.0837 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0561
# Epoch 22/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0066 - root_mean_squared_error: 0.0815 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0549
# Epoch 23/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0067 - root_mean_squared_error: 0.0818 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0547
# Epoch 24/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0060 - root_mean_squared_error: 0.0772 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0543
# Epoch 25/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0054 - root_mean_squared_error: 0.0737 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0531
# Epoch 1/25
# 21/21 [==============================] - 2s 27ms/step - loss: 0.3845 - root_mean_squared_error: 0.6201 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1048
# Epoch 2/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1389 - root_mean_squared_error: 0.3726 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1517
# Epoch 3/25
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0792 - root_mean_squared_error: 0.2814 - val_loss: 0.0283 - val_root_mean_squared_error: 0.1681
# Epoch 4/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0594 - root_mean_squared_error: 0.2437 - val_loss: 0.0266 - val_root_mean_squared_error: 0.1631
# Epoch 5/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0430 - root_mean_squared_error: 0.2074 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1517
# Epoch 6/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0321 - root_mean_squared_error: 0.1792 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1430
# Epoch 7/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0332 - root_mean_squared_error: 0.1822 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1300
# Epoch 8/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0256 - root_mean_squared_error: 0.1600 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1066
# Epoch 9/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0216 - root_mean_squared_error: 0.1471 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0964
# Epoch 10/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0192 - root_mean_squared_error: 0.1386 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0917
# Epoch 11/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0182 - root_mean_squared_error: 0.1351 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0901
# Epoch 12/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0151 - root_mean_squared_error: 0.1228 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0847
# Epoch 13/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0143 - root_mean_squared_error: 0.1197 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0780
# Epoch 14/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1199 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0699
# Epoch 15/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0112 - root_mean_squared_error: 0.1056 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0669
# Epoch 16/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0098 - root_mean_squared_error: 0.0988 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0680
# Epoch 17/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0098 - root_mean_squared_error: 0.0988 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0639
# Epoch 18/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0087 - root_mean_squared_error: 0.0934 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0656
# Epoch 19/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0079 - root_mean_squared_error: 0.0889 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0661
# Epoch 20/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0085 - root_mean_squared_error: 0.0922 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0632
# Epoch 21/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0075 - root_mean_squared_error: 0.0868 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0596
# Epoch 22/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0072 - root_mean_squared_error: 0.0849 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0572
# Epoch 23/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0061 - root_mean_squared_error: 0.0784 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0568
# Epoch 24/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0056 - root_mean_squared_error: 0.0748 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0522
# Epoch 25/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0053 - root_mean_squared_error: 0.0729 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0517
# Epoch 1/25
# 21/21 [==============================] - 3s 25ms/step - loss: 0.9378 - root_mean_squared_error: 0.9684 - val_loss: 0.0199 - val_root_mean_squared_error: 0.1410
# Epoch 2/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4279 - root_mean_squared_error: 0.6542 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1232
# Epoch 3/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2143 - root_mean_squared_error: 0.4629 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0987
# Epoch 4/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.1171 - root_mean_squared_error: 0.3422 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0959
# Epoch 5/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0616 - root_mean_squared_error: 0.2482 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0938
# Epoch 6/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0397 - root_mean_squared_error: 0.1992 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0830
# Epoch 7/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0253 - root_mean_squared_error: 0.1591 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0822
# Epoch 8/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0229 - root_mean_squared_error: 0.1513 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0816
# Epoch 9/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0228 - root_mean_squared_error: 0.1511 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0761
# Epoch 10/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0175 - root_mean_squared_error: 0.1324 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0808
# Epoch 11/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0196 - root_mean_squared_error: 0.1401 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0737
# Epoch 12/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0153 - root_mean_squared_error: 0.1237 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0782
# Epoch 13/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0170 - root_mean_squared_error: 0.1303 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0774
# Epoch 14/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0125 - root_mean_squared_error: 0.1118 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0693
# Epoch 15/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0108 - root_mean_squared_error: 0.1038 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0675
# Epoch 16/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0117 - root_mean_squared_error: 0.1083 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0671
# Epoch 17/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0651
# Epoch 18/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0102 - root_mean_squared_error: 0.1008 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0658
# Epoch 19/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0097 - root_mean_squared_error: 0.0985 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0647
# Epoch 20/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0106 - root_mean_squared_error: 0.1031 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0647
# Epoch 21/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0104 - root_mean_squared_error: 0.1019 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0655
# Epoch 22/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0093 - root_mean_squared_error: 0.0963 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0591
# Epoch 23/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0081 - root_mean_squared_error: 0.0902 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0588
# Epoch 24/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0081 - root_mean_squared_error: 0.0902 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0574
# Epoch 25/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0074 - root_mean_squared_error: 0.0858 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0594
# Epoch 1/25
# 21/21 [==============================] - 4s 31ms/step - loss: 0.2411 - root_mean_squared_error: 0.4911 - val_loss: 0.0510 - val_root_mean_squared_error: 0.2259
# Epoch 2/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0807 - root_mean_squared_error: 0.2841 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1347
# Epoch 3/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0499 - root_mean_squared_error: 0.2233 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1211
# Epoch 4/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0417 - root_mean_squared_error: 0.2042 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0984
# Epoch 5/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0414 - root_mean_squared_error: 0.2035 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1013
# Epoch 6/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0414 - root_mean_squared_error: 0.2034 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1018
# Epoch 7/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0283 - root_mean_squared_error: 0.1682 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0700
# Epoch 8/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0282 - root_mean_squared_error: 0.1679 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0827
# Epoch 9/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0261 - root_mean_squared_error: 0.1617 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0719
# Epoch 10/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0258 - root_mean_squared_error: 0.1608 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0761
# Epoch 11/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0202 - root_mean_squared_error: 0.1422 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0712
# Epoch 12/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0203 - root_mean_squared_error: 0.1425 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0605
# Epoch 13/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0217 - root_mean_squared_error: 0.1473 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0712
# Epoch 14/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0164 - root_mean_squared_error: 0.1283 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0770
# Epoch 15/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0134 - root_mean_squared_error: 0.1159 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0604
# Epoch 16/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0132 - root_mean_squared_error: 0.1150 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0550
# Epoch 17/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0108 - root_mean_squared_error: 0.1039 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0607
# Epoch 18/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0153 - root_mean_squared_error: 0.1237 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0519
# Epoch 19/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0103 - root_mean_squared_error: 0.1017 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0501
# Epoch 20/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0108 - root_mean_squared_error: 0.1039 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0584
# Epoch 21/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0086 - root_mean_squared_error: 0.0925 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0508
# Epoch 22/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0092 - root_mean_squared_error: 0.0958 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0524
# Epoch 23/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0079 - root_mean_squared_error: 0.0889 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0532
# Epoch 24/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0080 - root_mean_squared_error: 0.0894 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0488
# Epoch 25/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0072 - root_mean_squared_error: 0.0846 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0507
# Epoch 1/25
# 21/21 [==============================] - 2s 31ms/step - loss: 0.5033 - root_mean_squared_error: 0.7095 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0961
# Epoch 2/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1791 - root_mean_squared_error: 0.4232 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1114
# Epoch 3/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0841 - root_mean_squared_error: 0.2901 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1178
# Epoch 4/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0694 - root_mean_squared_error: 0.2634 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1108
# Epoch 5/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0613 - root_mean_squared_error: 0.2477 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0936
# Epoch 6/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0455 - root_mean_squared_error: 0.2132 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0964
# Epoch 7/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0409 - root_mean_squared_error: 0.2021 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0950
# Epoch 8/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0336 - root_mean_squared_error: 0.1834 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0889
# Epoch 9/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0287 - root_mean_squared_error: 0.1693 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0867
# Epoch 10/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0273 - root_mean_squared_error: 0.1652 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0861
# Epoch 11/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0235 - root_mean_squared_error: 0.1532 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0819
# Epoch 12/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0209 - root_mean_squared_error: 0.1445 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0817
# Epoch 13/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0195 - root_mean_squared_error: 0.1397 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0822
# Epoch 14/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0189 - root_mean_squared_error: 0.1376 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0785
# Epoch 15/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0159 - root_mean_squared_error: 0.1263 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0803
# Epoch 16/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0140 - root_mean_squared_error: 0.1184 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0756
# Epoch 17/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0135 - root_mean_squared_error: 0.1160 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0772
# Epoch 18/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0715
# Epoch 19/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0113 - root_mean_squared_error: 0.1061 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0705
# Epoch 20/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0115 - root_mean_squared_error: 0.1073 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0724
# Epoch 21/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0106 - root_mean_squared_error: 0.1031 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0686
# Epoch 22/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0092 - root_mean_squared_error: 0.0958 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0729
# Epoch 23/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0104 - root_mean_squared_error: 0.1020 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0673
# Epoch 24/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0085 - root_mean_squared_error: 0.0922 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0672
# Epoch 25/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0099 - root_mean_squared_error: 0.0995 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0654
# Epoch 1/25
# 21/21 [==============================] - 2s 27ms/step - loss: 0.3330 - root_mean_squared_error: 0.5770 - val_loss: 0.0264 - val_root_mean_squared_error: 0.1626
# Epoch 2/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1802 - root_mean_squared_error: 0.4245 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1169
# Epoch 3/25
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1532 - root_mean_squared_error: 0.3914 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1097
# Epoch 4/25
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1270 - root_mean_squared_error: 0.3564 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0992
# Epoch 5/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1157 - root_mean_squared_error: 0.3402 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1210
# Epoch 6/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0827 - root_mean_squared_error: 0.2877 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1113
# Epoch 7/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0840 - root_mean_squared_error: 0.2898 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1106
# Epoch 8/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0693 - root_mean_squared_error: 0.2633 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0959
# Epoch 9/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0554 - root_mean_squared_error: 0.2353 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0939
# Epoch 10/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0445 - root_mean_squared_error: 0.2111 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1005
# Epoch 11/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0424 - root_mean_squared_error: 0.2059 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1012
# Epoch 12/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0412 - root_mean_squared_error: 0.2030 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0846
# Epoch 13/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0395 - root_mean_squared_error: 0.1988 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0808
# Epoch 14/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0287 - root_mean_squared_error: 0.1693 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0800
# Epoch 15/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0325 - root_mean_squared_error: 0.1802 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0796
# Epoch 16/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0257 - root_mean_squared_error: 0.1603 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0765
# Epoch 17/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0330 - root_mean_squared_error: 0.1817 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0700
# Epoch 18/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0275 - root_mean_squared_error: 0.1659 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0725
# Epoch 19/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0745
# Epoch 20/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0200 - root_mean_squared_error: 0.1415 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0779
# Epoch 21/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0165 - root_mean_squared_error: 0.1283 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0805
# Epoch 22/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0199 - root_mean_squared_error: 0.1412 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0670
# Epoch 23/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0151 - root_mean_squared_error: 0.1231 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0647
# Epoch 24/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0119 - root_mean_squared_error: 0.1091 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0728
# Epoch 25/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0125 - root_mean_squared_error: 0.1120 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0657
# Epoch 1/25
# 21/21 [==============================] - 3s 25ms/step - loss: 0.2676 - root_mean_squared_error: 0.5173 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1297
# Epoch 2/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0806 - root_mean_squared_error: 0.2839 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1449
# Epoch 3/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0618 - root_mean_squared_error: 0.2486 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1071
# Epoch 4/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0402 - root_mean_squared_error: 0.2006 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0892
# Epoch 5/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0277 - root_mean_squared_error: 0.1665 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0801
# Epoch 6/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0255 - root_mean_squared_error: 0.1596 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0757
# Epoch 7/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0189 - root_mean_squared_error: 0.1376 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0727
# Epoch 8/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0212 - root_mean_squared_error: 0.1455 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0717
# Epoch 9/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0143 - root_mean_squared_error: 0.1197 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0697
# Epoch 10/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0137 - root_mean_squared_error: 0.1169 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0685
# Epoch 11/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0130 - root_mean_squared_error: 0.1141 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0645
# Epoch 12/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0116 - root_mean_squared_error: 0.1077 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0642
# Epoch 13/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0106 - root_mean_squared_error: 0.1028 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0627
# Epoch 14/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0098 - root_mean_squared_error: 0.0988 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0619
# Epoch 15/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0088 - root_mean_squared_error: 0.0940 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0594
# Epoch 16/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0088 - root_mean_squared_error: 0.0940 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0581
# Epoch 17/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0083 - root_mean_squared_error: 0.0910 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0582
# Epoch 18/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0069 - root_mean_squared_error: 0.0832 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0542
# Epoch 19/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0065 - root_mean_squared_error: 0.0803 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0534
# Epoch 20/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0064 - root_mean_squared_error: 0.0802 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0531
# Epoch 21/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0055 - root_mean_squared_error: 0.0743 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0527
# Epoch 22/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0052 - root_mean_squared_error: 0.0719 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0517
# Epoch 23/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0055 - root_mean_squared_error: 0.0741 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0507
# Epoch 24/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0045 - root_mean_squared_error: 0.0673 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0489
# Epoch 25/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0048 - root_mean_squared_error: 0.0692 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0497

# %%
# summarize history for loss
plt.plot(model1.history['loss'])
plt.plot(model1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# %tensorboard --logdir {logs_base_dir}
# Out:
# Reusing TensorBoard on port 6006 (pid 17244), started 2 days, 23:07:56 ago. (Use '!kill 17244' to kill it.)
#       <iframe id="tensorboard-frame-49f605418818a00b" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-49f605418818a00b");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
#Final model
# WModel save
callbacks = tf.keras.callbacks.ModelCheckpoint(filepath + "M1", save_best_only = True)
for train_index, val_index in kfold_generator.split(df_x, df_y):
    # Split training dataset.
    train_x, train_y = df_x.iloc[train_index], df_y.iloc[train_index]
    # Split validation dataset.
    val_x, val_y = df_x.iloc[val_index], df_y.iloc[val_index]
    # Make tensor dataset.
    ##tf_train = tf.data.Dataset.from_tensor_slices((train_x, train_y)).shuffle(2022).batch(500, drop_remainder=True).prefetch(1)
    ##tf_val = tf.data.Dataset.from_tensor_slices((val_x, val_y)).shuffle(2022).batch(1024, drop_remainder=True).prefetch(1)
    # Load model
    model = pythonash_model()
    # Model fitting
    
    model1 = model.fit(train_x, train_y, callbacks = callbacks, batch_size=64, epochs = 12, ### change the epochs into more numbers.
             validation_data = (val_x, val_y), shuffle=True)
    # Delete tensor dataset and model to save memory
    del model
    ##del tf_train
    ##del tf_val
    
best_model = tf.keras.models.load_model("M1")   
pred1 = best_model.predict(test_x)
# Out:
# Epoch 1/12
# 20/21 [===========================>..] - ETA: 0s - loss: 0.4273 - root_mean_squared_error: 0.6537 INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 6s 188ms/step - loss: 0.4274 - root_mean_squared_error: 0.6537 - val_loss: 0.0414 - val_root_mean_squared_error: 0.2034
# Epoch 2/12
# 15/21 [====================>.........] - ETA: 0s - loss: 0.2045 - root_mean_squared_error: 0.4522INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 4s 201ms/step - loss: 0.1779 - root_mean_squared_error: 0.4218 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1579
# Epoch 3/12
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0846 - root_mean_squared_error: 0.2909INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 4s 182ms/step - loss: 0.0839 - root_mean_squared_error: 0.2896 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1129
# Epoch 4/12
# 17/21 [=======================>......] - ETA: 0s - loss: 0.0673 - root_mean_squared_error: 0.2595INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 3s 166ms/step - loss: 0.0673 - root_mean_squared_error: 0.2593 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1056
# Epoch 5/12
# 12/21 [================>.............] - ETA: 0s - loss: 0.0678 - root_mean_squared_error: 0.2603INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 4s 179ms/step - loss: 0.0679 - root_mean_squared_error: 0.2606 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1034
# Epoch 6/12
# 13/21 [=================>............] - ETA: 0s - loss: 0.0722 - root_mean_squared_error: 0.2687INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 4s 201ms/step - loss: 0.0711 - root_mean_squared_error: 0.2667 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1016
# Epoch 7/12
# 11/21 [==============>...............] - ETA: 0s - loss: 0.0355 - root_mean_squared_error: 0.1884INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 4s 188ms/step - loss: 0.0363 - root_mean_squared_error: 0.1906 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0973
# Epoch 8/12
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0363 - root_mean_squared_error: 0.1906 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0984
# Epoch 9/12
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0409 - root_mean_squared_error: 0.2022INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 3s 162ms/step - loss: 0.0395 - root_mean_squared_error: 0.1987 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0960
# Epoch 10/12
# 12/21 [================>.............] - ETA: 0s - loss: 0.0453 - root_mean_squared_error: 0.2128INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 4s 184ms/step - loss: 0.0379 - root_mean_squared_error: 0.1948 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0936
# Epoch 11/12
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0245 - root_mean_squared_error: 0.1566 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1103
# Epoch 12/12
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0247 - root_mean_squared_error: 0.1572 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1016
# Epoch 1/12
# 21/21 [==============================] - 2s 16ms/step - loss: 0.3409 - root_mean_squared_error: 0.5839 - val_loss: 0.0203 - val_root_mean_squared_error: 0.1425
# Epoch 2/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1252 - root_mean_squared_error: 0.3538 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0990
# Epoch 3/12
# 17/21 [=======================>......] - ETA: 0s - loss: 0.0918 - root_mean_squared_error: 0.3029INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 4s 207ms/step - loss: 0.0905 - root_mean_squared_error: 0.3008 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0882
# Epoch 4/12
# 17/21 [=======================>......] - ETA: 0s - loss: 0.0642 - root_mean_squared_error: 0.2534INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 3s 157ms/step - loss: 0.0639 - root_mean_squared_error: 0.2528 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0813
# Epoch 5/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0817 - root_mean_squared_error: 0.2858 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0852
# Epoch 6/12
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0574 - root_mean_squared_error: 0.2395INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 3s 163ms/step - loss: 0.0589 - root_mean_squared_error: 0.2427 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0759
# Epoch 7/12
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0528 - root_mean_squared_error: 0.2298 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0783
# Epoch 8/12
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0417 - root_mean_squared_error: 0.2041 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0773
# Epoch 9/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0289 - root_mean_squared_error: 0.1701 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0787
# Epoch 10/12
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0458 - root_mean_squared_error: 0.2140 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0759
# Epoch 11/12
# 14/21 [===================>..........] - ETA: 0s - loss: 0.0434 - root_mean_squared_error: 0.2084INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 3s 173ms/step - loss: 0.0359 - root_mean_squared_error: 0.1893 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0700
# Epoch 12/12
# 18/21 [========================>.....] - ETA: 0s - loss: 0.0225 - root_mean_squared_error: 0.1501INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 4s 197ms/step - loss: 0.0217 - root_mean_squared_error: 0.1473 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0669
# Epoch 1/12
# 21/21 [==============================] - 2s 22ms/step - loss: 0.1844 - root_mean_squared_error: 0.4295 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0969
# Epoch 2/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0724 - root_mean_squared_error: 0.2691 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0997
# Epoch 3/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0476 - root_mean_squared_error: 0.2181 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0877
# Epoch 4/12
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0408 - root_mean_squared_error: 0.2020 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0803
# Epoch 5/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0309 - root_mean_squared_error: 0.1757 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0748
# Epoch 6/12
# 16/21 [=====================>........] - ETA: 0s - loss: 0.0303 - root_mean_squared_error: 0.1741INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 3s 151ms/step - loss: 0.0293 - root_mean_squared_error: 0.1710 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0616
# Epoch 7/12
# 21/21 [==============================] - ETA: 0s - loss: 0.0223 - root_mean_squared_error: 0.1492INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 4s 175ms/step - loss: 0.0223 - root_mean_squared_error: 0.1492 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611
# Epoch 8/12
# 21/21 [==============================] - ETA: 0s - loss: 0.0208 - root_mean_squared_error: 0.1444INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 3s 161ms/step - loss: 0.0208 - root_mean_squared_error: 0.1444 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0589
# Epoch 9/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0223 - root_mean_squared_error: 0.1493 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0592
# Epoch 10/12
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0151 - root_mean_squared_error: 0.1231INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 5s 225ms/step - loss: 0.0152 - root_mean_squared_error: 0.1232 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0574
# Epoch 11/12
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0142 - root_mean_squared_error: 0.1191INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 3s 167ms/step - loss: 0.0137 - root_mean_squared_error: 0.1170 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0550
# Epoch 12/12
# 14/21 [===================>..........] - ETA: 0s - loss: 0.0118 - root_mean_squared_error: 0.1084INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 3s 168ms/step - loss: 0.0113 - root_mean_squared_error: 0.1061 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0520
# Epoch 1/12
# 21/21 [==============================] - 2s 17ms/step - loss: 0.6152 - root_mean_squared_error: 0.7844 - val_loss: 0.0194 - val_root_mean_squared_error: 0.1393
# Epoch 2/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2236 - root_mean_squared_error: 0.4729 - val_loss: 0.0253 - val_root_mean_squared_error: 0.1590
# Epoch 3/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1146 - root_mean_squared_error: 0.3385 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1516
# Epoch 4/12
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0641 - root_mean_squared_error: 0.2532 - val_loss: 0.0232 - val_root_mean_squared_error: 0.1524
# Epoch 5/12
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0569 - root_mean_squared_error: 0.2385 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1300
# Epoch 6/12
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0455 - root_mean_squared_error: 0.2134 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1144
# Epoch 7/12
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0359 - root_mean_squared_error: 0.1895 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1025
# Epoch 8/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0394 - root_mean_squared_error: 0.1984 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1048
# Epoch 9/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0321 - root_mean_squared_error: 0.1790 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0924
# Epoch 10/12
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0300 - root_mean_squared_error: 0.1731 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0919
# Epoch 11/12
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0269 - root_mean_squared_error: 0.1641 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0821
# Epoch 12/12
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0203 - root_mean_squared_error: 0.1423 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0838
# Epoch 1/12
# 21/21 [==============================] - 2s 16ms/step - loss: 0.6665 - root_mean_squared_error: 0.8164 - val_loss: 0.0244 - val_root_mean_squared_error: 0.1561
# Epoch 2/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2811 - root_mean_squared_error: 0.5302 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1342
# Epoch 3/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1881 - root_mean_squared_error: 0.4337 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1099
# Epoch 4/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1073 - root_mean_squared_error: 0.3275 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1136
# Epoch 5/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0863 - root_mean_squared_error: 0.2938 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1021
# Epoch 6/12
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0803 - root_mean_squared_error: 0.2834 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0972
# Epoch 7/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0632 - root_mean_squared_error: 0.2515 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0893
# Epoch 8/12
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0474 - root_mean_squared_error: 0.2177 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0824
# Epoch 9/12
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0783 - root_mean_squared_error: 0.2798 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0882
# Epoch 10/12
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0380 - root_mean_squared_error: 0.1948 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0854
# Epoch 11/12
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0330 - root_mean_squared_error: 0.1817 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0843
# Epoch 12/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0346 - root_mean_squared_error: 0.1861 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0800
# Epoch 1/12
# 21/21 [==============================] - 2s 23ms/step - loss: 0.7141 - root_mean_squared_error: 0.8450 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2010
# Epoch 2/12
# 21/21 [==============================] - 0s 3ms/step - loss: 0.2394 - root_mean_squared_error: 0.4893 - val_loss: 0.0406 - val_root_mean_squared_error: 0.2015
# Epoch 3/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1220 - root_mean_squared_error: 0.3493 - val_loss: 0.0694 - val_root_mean_squared_error: 0.2635
# Epoch 4/12
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0961 - root_mean_squared_error: 0.3100 - val_loss: 0.0647 - val_root_mean_squared_error: 0.2544
# Epoch 5/12
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0786 - root_mean_squared_error: 0.2803 - val_loss: 0.0452 - val_root_mean_squared_error: 0.2126
# Epoch 6/12
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0640 - root_mean_squared_error: 0.2529 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2012
# Epoch 7/12
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0567 - root_mean_squared_error: 0.2381 - val_loss: 0.0383 - val_root_mean_squared_error: 0.1957
# Epoch 8/12
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0483 - root_mean_squared_error: 0.2197 - val_loss: 0.0310 - val_root_mean_squared_error: 0.1761
# Epoch 9/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0465 - root_mean_squared_error: 0.2157 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1569
# Epoch 10/12
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0415 - root_mean_squared_error: 0.2037 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1490
# Epoch 11/12
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0359 - root_mean_squared_error: 0.1896 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1278
# Epoch 12/12
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0339 - root_mean_squared_error: 0.1840 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1264
# Epoch 1/12
# 21/21 [==============================] - 2s 20ms/step - loss: 0.7923 - root_mean_squared_error: 0.8901 - val_loss: 0.0778 - val_root_mean_squared_error: 0.2790
# Epoch 2/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3002 - root_mean_squared_error: 0.5479 - val_loss: 0.0451 - val_root_mean_squared_error: 0.2124
# Epoch 3/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2397 - root_mean_squared_error: 0.4896 - val_loss: 0.0395 - val_root_mean_squared_error: 0.1986
# Epoch 4/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1590 - root_mean_squared_error: 0.3988 - val_loss: 0.0334 - val_root_mean_squared_error: 0.1826
# Epoch 5/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1710 - root_mean_squared_error: 0.4136 - val_loss: 0.0302 - val_root_mean_squared_error: 0.1739
# Epoch 6/12
# 21/21 [==============================] - 0s 7ms/step - loss: 0.1455 - root_mean_squared_error: 0.3814 - val_loss: 0.0356 - val_root_mean_squared_error: 0.1888
# Epoch 7/12
# 21/21 [==============================] - 0s 7ms/step - loss: 0.1357 - root_mean_squared_error: 0.3684 - val_loss: 0.0287 - val_root_mean_squared_error: 0.1694
# Epoch 8/12
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0997 - root_mean_squared_error: 0.3158 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1478
# Epoch 9/12
# 21/21 [==============================] - 0s 7ms/step - loss: 0.1132 - root_mean_squared_error: 0.3364 - val_loss: 0.0281 - val_root_mean_squared_error: 0.1677
# Epoch 10/12
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0949 - root_mean_squared_error: 0.3081 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1448
# Epoch 11/12
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0875 - root_mean_squared_error: 0.2958 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1481
# Epoch 12/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0676 - root_mean_squared_error: 0.2600 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1321
# Epoch 1/12
# 21/21 [==============================] - 2s 16ms/step - loss: 0.4292 - root_mean_squared_error: 0.6552 - val_loss: 0.0299 - val_root_mean_squared_error: 0.1729
# Epoch 2/12
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1743 - root_mean_squared_error: 0.4175 - val_loss: 0.0287 - val_root_mean_squared_error: 0.1693
# Epoch 3/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1270 - root_mean_squared_error: 0.3563 - val_loss: 0.0261 - val_root_mean_squared_error: 0.1616
# Epoch 4/12
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0909 - root_mean_squared_error: 0.3014 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1415
# Epoch 5/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0775 - root_mean_squared_error: 0.2783 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1457
# Epoch 6/12
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0673 - root_mean_squared_error: 0.2594 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1416
# Epoch 7/12
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0479 - root_mean_squared_error: 0.2190 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1403
# Epoch 8/12
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0416 - root_mean_squared_error: 0.2040 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1297
# Epoch 9/12
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0364 - root_mean_squared_error: 0.1909 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1300
# Epoch 10/12
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0370 - root_mean_squared_error: 0.1923 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1183
# Epoch 11/12
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0317 - root_mean_squared_error: 0.1780 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1148
# Epoch 12/12
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0314 - root_mean_squared_error: 0.1772 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1122
# Epoch 1/12
# 21/21 [==============================] - 2s 15ms/step - loss: 0.1877 - root_mean_squared_error: 0.4333 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0630
# Epoch 2/12
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0579 - root_mean_squared_error: 0.2407 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0955
# Epoch 3/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0389 - root_mean_squared_error: 0.1974 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1014
# Epoch 4/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0274 - root_mean_squared_error: 0.1656 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0829
# Epoch 5/12
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0224 - root_mean_squared_error: 0.1495 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0723
# Epoch 6/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0176 - root_mean_squared_error: 0.1328 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0691
# Epoch 7/12
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0124 - root_mean_squared_error: 0.1114 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0609
# Epoch 8/12
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0132 - root_mean_squared_error: 0.1147 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0575
# Epoch 9/12
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0103 - root_mean_squared_error: 0.1017 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0543
# Epoch 10/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0091 - root_mean_squared_error: 0.0955 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0534
# Epoch 11/12
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0090 - root_mean_squared_error: 0.0951 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0536
# Epoch 12/12
# 21/21 [==============================] - ETA: 0s - loss: 0.0083 - root_mean_squared_error: 0.0910INFO:tensorflow:Assets written to: M1\assets
# 21/21 [==============================] - 3s 172ms/step - loss: 0.0083 - root_mean_squared_error: 0.0910 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0503
# Epoch 1/12
# 21/21 [==============================] - 2s 18ms/step - loss: 0.6525 - root_mean_squared_error: 0.8078 - val_loss: 0.0209 - val_root_mean_squared_error: 0.1447
# Epoch 2/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2424 - root_mean_squared_error: 0.4923 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1233
# Epoch 3/12
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1198 - root_mean_squared_error: 0.3461 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1208
# Epoch 4/12
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0906 - root_mean_squared_error: 0.3010 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1178
# Epoch 5/12
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0658 - root_mean_squared_error: 0.2565 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1165
# Epoch 6/12
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0651 - root_mean_squared_error: 0.2551 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1081
# Epoch 7/12
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0513 - root_mean_squared_error: 0.2265 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1045
# Epoch 8/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0541 - root_mean_squared_error: 0.2326 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1128
# Epoch 9/12
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0403 - root_mean_squared_error: 0.2006 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0905
# Epoch 10/12
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0366 - root_mean_squared_error: 0.1914 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0872
# Epoch 11/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0357 - root_mean_squared_error: 0.1890 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0902
# Epoch 12/12
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0322 - root_mean_squared_error: 0.1793 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0969

# %%
from matplotlib.pyplot import figure

figure(figsize=(20,8), dpi=80)

plt.plot(btc["1_Day_Price_Diff_Percent"][1500:1875].values, label = "Real")
plt.plot(pred1, label = "Pred")

plt.xlabel('Day')
# naming the y axis
plt.ylabel('Daily price difference in percent')
# giving a title to my graph
plt.title('Bitcoin price prediction')
  
# show a legend on the plot
plt.legend()
  
# function to show the plot
plt.show()
rmse_(btc["1_Day_Price_Diff_Percent"][1500:1875].values,pred1)
# Out:
# RMSE : 0.04245313420719013

# %%
figure(figsize=(20,8), dpi=80)

pred_price = []
for num1, num2 in zip(pred1, btc["Close"][1500:1875].values):
	pred_price.append((num1 * num2) + num2)

plt.plot(btc["1_Day_Price"][1500:1875].values, label = "Real")
plt.plot(pred_price, label = "Pred")

plt.xlabel('Day')
# naming the y axis
plt.ylabel('Price in Us Dollar')
# giving a title to my graph
plt.title('Bitcoin price prediction')
  
# show a legend on the plot
plt.legend()
  
# function to show the plot
plt.show()
#rmse_(btc["1_Day_Price"][1500:1875].values,pred_price)

# %% [markdown]
# **Twitter**

# %% [markdown]
# Dowload data

# %%
tweet = pd.read_csv("C:/Users/Jérémy Olivier/Documents/Université/Master/2 semester/Advanced programming/Project/tweet_compound.csv")
tweet.head(2)
# Out:
#    Unnamed: 0            id          user fullname                    Date  \
# 0    11291156  3.286741e+07  chrispychong  chrispy  2007-04-19 07:14:38+00
# 1          21  1.110303e+09        halfin   halfin  2009-01-11 03:33:52+00
#
#    replies  likes  retweets  \
# 0        0      0         2
# 1      790  14470      5542
#
#                                                 text  compound
# 0  is happily mugging at BTC where she will hook ...    0.8516
# 1                                  Running bitcoin\r    0.0000

# %%
#Date
tweet['Date'] = pd.to_datetime(tweet['Date']).dt.strftime('%Y-%m-%d')
tweet.index = tweet['Date']
tweet.index.names = ['date']
tweet = tweet.sort_values(by = 'Date')

# %%
tweet.groupby(['Date']).mean().reset_index()

tt =tweet.groupby(['Date']).sum().reset_index()
tt.rename(columns={'likes':'tot_likes'}, inplace=True)

tweet["score"] = (tweet["compound"] * tweet["likes"])
tweet_compound = tweet.groupby(['Date']).sum().reset_index()
tweet_compound["score"] = tweet_compound["score"] / tt["tot_likes"]


tweet_count = tweet.groupby(['Date']).size().reset_index(name='counts')

# %%
tweet_count["_1_counts"] = tweet_count['counts'].shift(periods = 1) #counts of the day before
tweet_count["_1_counts_diff"] = tweet_count["counts"] - tweet_count["_1_counts"] #Difference between the counts T-1 and T0
tweet_count["_1_counts_diff_percent"] = tweet_count["_1_counts_diff"] / tweet_count["_1_counts"] #Difference between the counts T-1 and T0 in Percent
tweet_count['SMA_7_counts'] = tweet_count["_1_counts_diff_percent"].rolling(window=7).mean() 
tweet_count['SMA_14_counts'] = tweet_count["_1_counts_diff_percent"].rolling(window=14).mean()
tweet_count['SMA_21_counts'] = tweet_count["_1_counts_diff_percent"].rolling(window=21).mean()
for i in range(1,15):
    tweet_count["counts",i] = tweet_count['_1_counts_diff_percent'].shift(periods = i) #old volume on 14 days

tweet_compound["score"] = tweet_compound["score"] + 1
tweet_compound["_1_score"] = tweet_compound["score"].shift(periods = 1) #counts of the day before
tweet_compound["_1_score_diff"] = tweet_compound["score"] - tweet_compound["_1_score"] #Difference between the counts T-1 and T0
tweet_compound["_1_score_diff_percent"] = tweet_compound["_1_score_diff"] / tweet_compound["_1_score"] #Difference between the counts T-1 and T0 in Percent
tweet_compound['SMA_7_score'] = tweet_compound["_1_score_diff_percent"].rolling(window=7).mean() 
tweet_compound['SMA_14_score'] = tweet_compound["_1_score_diff_percent"].rolling(window=14).mean()
tweet_compound['SMA_21_score'] = tweet_compound["_1_score_diff_percent"].rolling(window=21).mean()
for i in range(1,15):
    tweet_compound["score",i] = tweet_compound['_1_score_diff_percent'].shift(periods = i) #old volume on 14 days

# %%
df = btc.merge(tweet_count, how = 'inner', on='Date')
df = df.merge(tweet_compound, how = 'inner', on='Date')

# %%
df[1500:1875]
plt.figure(figsize = (18,9))
plt.plot(range(df.shape[0]),df["counts"])
plt.xticks(range(0,df.shape[0],500),df['Date'].loc[::500],rotation=45)
plt.xlabel('Date',fontsize=18)
plt.ylabel('Count',fontsize=18)
plt.title("Number of tweets per day")
plt.show()

# %%
no_features = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', '1_Day_Price', '1_Day_Price_Diff', 
               '1_Day_Price_Diff_Percent','_1_Day_Price', '_1_Day_Price_Diff', '_1_Day_Vol', '_1_Day_Vol_Diff' , 'id', 
               'replies','likes','retweets','compound', 'score', '_1_score', '_1_score_diff', '_1_score_diff_percent', 
                'counts', '_1_counts', '_1_counts_diff','_1_counts_diff_percent']
df_test = df.drop(no_features, 1)

# %%
df_test.hist(bins=30, figsize=(30, 20))
# Out:
# array([[<AxesSubplot:title={'center':'_1_Day_Vol_Diff_Percent'}>,
#         <AxesSubplot:title={'center':'SMA_7_Volume'}>,
#         <AxesSubplot:title={'center':'SMA_14_Volume'}>,
#         <AxesSubplot:title={'center':'SMA_21_Volume'}>,
#         <AxesSubplot:title={'center':'_1_Day_Price_Diff_Percent'}>,
#         <AxesSubplot:title={'center':'SMA_7_Price'}>,
#         <AxesSubplot:title={'center':'SMA_14_Price'}>,
#         <AxesSubplot:title={'center':'SMA_21_Price'}>],
#        [<AxesSubplot:title={'center':"('Vol', 1)"}>,
#         <AxesSubplot:title={'center':"('Vol', 2)"}>,
#         <AxesSubplot:title={'center':"('Vol', 3)"}>,
#         <AxesSubplot:title={'center':"('Vol', 4)"}>,
#         <AxesSubplot:title={'center':"('Vol', 5)"}>,
#         <AxesSubplot:title={'center':"('Vol', 6)"}>,
#         <AxesSubplot:title={'center':"('Vol', 7)"}>,
#         <AxesSubplot:title={'center':"('Vol', 8)"}>],
#        [<AxesSubplot:title={'center':"('Vol', 9)"}>,
#         <AxesSubplot:title={'center':"('Vol', 10)"}>,
#         <AxesSubplot:title={'center':"('Vol', 11)"}>,
#         <AxesSubplot:title={'center':"('Vol', 12)"}>,
#         <AxesSubplot:title={'center':"('Vol', 13)"}>,
#         <AxesSubplot:title={'center':"('Vol', 14)"}>,
#         <AxesSubplot:title={'center':"('Price', 1)"}>,
#         <AxesSubplot:title={'center':"('Price', 2)"}>],
#        [<AxesSubplot:title={'center':"('Price', 3)"}>,
#         <AxesSubplot:title={'center':"('Price', 4)"}>,
#         <AxesSubplot:title={'center':"('Price', 5)"}>,
#         <AxesSubplot:title={'center':"('Price', 6)"}>,
#         <AxesSubplot:title={'center':"('Price', 7)"}>,
#         <AxesSubplot:title={'center':"('Price', 8)"}>,
#         <AxesSubplot:title={'center':"('Price', 9)"}>,
#         <AxesSubplot:title={'center':"('Price', 10)"}>],
#        [<AxesSubplot:title={'center':"('Price', 11)"}>,
#         <AxesSubplot:title={'center':"('Price', 12)"}>,
#         <AxesSubplot:title={'center':"('Price', 13)"}>,
#         <AxesSubplot:title={'center':"('Price', 14)"}>,
#         <AxesSubplot:title={'center':'SMA_7_counts'}>,
#         <AxesSubplot:title={'center':'SMA_14_counts'}>,
#         <AxesSubplot:title={'center':'SMA_21_counts'}>,
#         <AxesSubplot:title={'center':"('counts', 1)"}>],
#        [<AxesSubplot:title={'center':"('counts', 2)"}>,
#         <AxesSubplot:title={'center':"('counts', 3)"}>,
#         <AxesSubplot:title={'center':"('counts', 4)"}>,
#         <AxesSubplot:title={'center':"('counts', 5)"}>,
#         <AxesSubplot:title={'center':"('counts', 6)"}>,
#         <AxesSubplot:title={'center':"('counts', 7)"}>,
#         <AxesSubplot:title={'center':"('counts', 8)"}>,
#         <AxesSubplot:title={'center':"('counts', 9)"}>],
#        [<AxesSubplot:title={'center':"('counts', 10)"}>,
#         <AxesSubplot:title={'center':"('counts', 11)"}>,
#         <AxesSubplot:title={'center':"('counts', 12)"}>,
#         <AxesSubplot:title={'center':"('counts', 13)"}>,
#         <AxesSubplot:title={'center':"('counts', 14)"}>,
#         <AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'SMA_7_score'}>,
#         <AxesSubplot:title={'center':'SMA_14_score'}>],
#        [<AxesSubplot:title={'center':'SMA_21_score'}>,
#         <AxesSubplot:title={'center':"('score', 1)"}>,
#         <AxesSubplot:title={'center':"('score', 2)"}>,
#         <AxesSubplot:title={'center':"('score', 3)"}>,
#         <AxesSubplot:title={'center':"('score', 4)"}>,
#         <AxesSubplot:title={'center':"('score', 5)"}>,
#         <AxesSubplot:title={'center':"('score', 6)"}>,
#         <AxesSubplot:title={'center':"('score', 7)"}>],
#        [<AxesSubplot:title={'center':"('score', 8)"}>,
#         <AxesSubplot:title={'center':"('score', 9)"}>,
#         <AxesSubplot:title={'center':"('score', 10)"}>,
#         <AxesSubplot:title={'center':"('score', 11)"}>,
#         <AxesSubplot:title={'center':"('score', 12)"}>,
#         <AxesSubplot:title={'center':"('score', 13)"}>,
#         <AxesSubplot:title={'center':"('score', 14)"}>, <AxesSubplot:>]],
#       dtype=object)

# %%
no_features = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', '1_Day_Price', '1_Day_Price_Diff', 
               '1_Day_Price_Diff_Percent','_1_Day_Price', '_1_Day_Price_Diff', '_1_Day_Vol', '_1_Day_Vol_Diff' , 'id', 
               'replies','likes','retweets','compound', 'score', '_1_score', '_1_score_diff', '_1_score_diff_percent', 
                'counts', '_1_counts', '_1_counts_diff','_1_counts_diff_percent']
x_train = df.drop(no_features, 1)


import random
random.seed(2022)
tf.random.set_seed(2022)
initializer = tf.keras.initializers.HeNormal(seed=2022)
def pythonash_model():
    inputs_ = tf.keras.Input(shape = [x_train.shape[1]])
    x = tf.keras.layers.Dense(32, kernel_initializer = initializer)(inputs_)
    batch = tf.keras.layers.BatchNormalization()(x)
    leaky = tf.keras.layers.LeakyReLU(0.1)(batch)
    
    x = tf.keras.layers.Dense(32, kernel_initializer = initializer)(leaky)
    batch = tf.keras.layers.BatchNormalization()(x)
    leaky = tf.keras.layers.LeakyReLU(0.1)(batch)
    
    x = tf.keras.layers.Dense(64, kernel_initializer = initializer)(leaky)
    batch = tf.keras.layers.BatchNormalization()(x)
    leaky = tf.keras.layers.LeakyReLU(0.1)(batch)

    x = tf.keras.layers.Dense(64, kernel_initializer = initializer)(leaky)
    batch = tf.keras.layers.BatchNormalization()(x)
    leaky = tf.keras.layers.LeakyReLU(0.1)(batch)
    
    x = tf.keras.layers.Dense(32, kernel_initializer = initializer)(leaky)
    batch = tf.keras.layers.BatchNormalization()(x)
    leaky = tf.keras.layers.LeakyReLU(0.1)(batch)
    drop = tf.keras.layers.Dropout(0.1)(leaky) #Dropout to avoid overfitting
    
    x = tf.keras.layers.Dense(32, kernel_initializer = initializer)(leaky)
    batch = tf.keras.layers.BatchNormalization()(x)
    leaky = tf.keras.layers.LeakyReLU(0.1)(batch)
    
    x = tf.keras.layers.Dense(16, kernel_initializer = initializer)(leaky)
    batch = tf.keras.layers.BatchNormalization()(x)
    leaky = tf.keras.layers.LeakyReLU(0.1)(batch)
    drop = tf.keras.layers.Dropout(0.1)(leaky) #Dropout to avoid overfitting
    
    x = tf.keras.layers.Dense(8, kernel_initializer = initializer)(leaky)
    batch = tf.keras.layers.BatchNormalization()(x)
    leaky = tf.keras.layers.LeakyReLU(0.1)(batch)
    drop = tf.keras.layers.Dropout(0.1)(leaky) #Dropout to avoid overfitting
    
    outputs_ = tf.keras.layers.Dense(1)(drop)
    
    model = tf.keras.Model(inputs = inputs_, outputs = outputs_)
    
    rmse = tf.keras.metrics.RootMeanSquaredError()

    learning_sch = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate = 0.0015,
    decay_steps = 1500,
    decay_rate = 0.95)
    adam = tf.keras.optimizers.Adam(learning_rate = learning_sch)
    
    model.compile(loss = 'mse', metrics = [rmse,], optimizer = adam) #adam optimizer!!
    return model

#pythonash_model().summary()

# %%
import graphviz
import pydot
tf.keras.utils.plot_model(pythonash_model(),show_shapes=True,expand_nested=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
from sklearn.preprocessing import StandardScaler
df_x = df.drop(no_features, axis=1)[25:1500]
df_y = df["1_Day_Price_Diff_Percent"][25:1500]

test_x = df.drop(no_features, axis=1)[1500:1875]
test_y = df["1_Day_Price_Diff_Percent"][1500:1875]

#scale data because of vriable of score
scaler = StandardScaler()
df_x = pd.DataFrame(scaler.fit_transform(df_x))
test_x = pd.DataFrame(scaler.transform(test_x))

# %%
kfold_generator = KFold(n_splits =10, shuffle=True, random_state = 2022)
kfold_generator
# Out:
# KFold(n_splits=10, random_state=2022, shuffle=True)

# %%
# Final model
# WModel save
#callbacks = tf.keras.callbacks.ModelCheckpoint(filepath + "M2", save_best_only = True)
for train_index, val_index in kfold_generator.split(df_x, df_y):
    # Split training dataset.
    train_x, train_y = df_x.iloc[train_index], df_y.iloc[train_index]
    # Split validation dataset.
    val_x, val_y = df_x.iloc[val_index], df_y.iloc[val_index]
    # Make tensor dataset.
    ##tf_train = tf.data.Dataset.from_tensor_slices((train_x, train_y)).shuffle(2022).batch(500, drop_remainder=True).prefetch(1)
    ##tf_val = tf.data.Dataset.from_tensor_slices((val_x, val_y)).shuffle(2022).batch(1024, drop_remainder=True).prefetch(1)
    # Load model
    model = pythonash_model()
    # Model fitting
    logdir = os.path.join(logs_base_dir, datetime.now().strftime("%Y%m%d-%H%M%S"))
    tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=25)
    model2 = model.fit(train_x, train_y, callbacks = tensorboard_callback, batch_size=64, epochs = 25, ### change the epochs into more numbers.
             validation_data = (val_x, val_y), shuffle=True)
    # Delete tensor dataset and model to save memory
    del model
    ##del tf_train
    ##del tf_val
    
#best_model = tf.keras.models.load_model(filepath + "M2")   
#pred2 = best_model.predict(test_x)
# Out:
# Epoch 1/25
# 21/21 [==============================] - 3s 33ms/step - loss: 0.3330 - root_mean_squared_error: 0.5771 - val_loss: 0.0661 - val_root_mean_squared_error: 0.2571
# Epoch 2/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1040 - root_mean_squared_error: 0.3225 - val_loss: 0.0332 - val_root_mean_squared_error: 0.1822
# Epoch 3/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0437 - root_mean_squared_error: 0.2090 - val_loss: 0.0306 - val_root_mean_squared_error: 0.1749
# Epoch 4/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0332 - root_mean_squared_error: 0.1821 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1328
# Epoch 5/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0256 - root_mean_squared_error: 0.1601 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1319
# Epoch 6/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0213 - root_mean_squared_error: 0.1459 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1113
# Epoch 7/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0977
# Epoch 8/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0183 - root_mean_squared_error: 0.1352 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 9/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0172 - root_mean_squared_error: 0.1311 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0760
# Epoch 10/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0131 - root_mean_squared_error: 0.1147 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0682
# Epoch 11/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0139 - root_mean_squared_error: 0.1178 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0652
# Epoch 12/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0132 - root_mean_squared_error: 0.1148 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0581
# Epoch 13/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0106 - root_mean_squared_error: 0.1029 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0546
# Epoch 14/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0105 - root_mean_squared_error: 0.1026 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0543
# Epoch 15/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0091 - root_mean_squared_error: 0.0953 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0530
# Epoch 16/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0084 - root_mean_squared_error: 0.0917 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0517
# Epoch 17/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0083 - root_mean_squared_error: 0.0913 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0508
# Epoch 18/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0079 - root_mean_squared_error: 0.0891 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0495
# Epoch 19/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0077 - root_mean_squared_error: 0.0878 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0482
# Epoch 20/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0073 - root_mean_squared_error: 0.0852 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0462
# Epoch 21/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0070 - root_mean_squared_error: 0.0837 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0451
# Epoch 22/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0060 - root_mean_squared_error: 0.0773 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0439
# Epoch 23/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0068 - root_mean_squared_error: 0.0824 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0447
# Epoch 24/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0059 - root_mean_squared_error: 0.0767 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0443
# Epoch 25/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0054 - root_mean_squared_error: 0.0733 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0430
# Epoch 1/25
# 21/21 [==============================] - 2s 31ms/step - loss: 1.1157 - root_mean_squared_error: 1.0563 - val_loss: 1.3429 - val_root_mean_squared_error: 1.1588
# Epoch 2/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.3994 - root_mean_squared_error: 0.6320 - val_loss: 0.4355 - val_root_mean_squared_error: 0.6599
# Epoch 3/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2169 - root_mean_squared_error: 0.4657 - val_loss: 0.2248 - val_root_mean_squared_error: 0.4741
# Epoch 4/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1791 - root_mean_squared_error: 0.4232 - val_loss: 0.1387 - val_root_mean_squared_error: 0.3724
# Epoch 5/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1283 - root_mean_squared_error: 0.3582 - val_loss: 0.1031 - val_root_mean_squared_error: 0.3211
# Epoch 6/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.1228 - root_mean_squared_error: 0.3505 - val_loss: 0.0778 - val_root_mean_squared_error: 0.2789
# Epoch 7/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0991 - root_mean_squared_error: 0.3147 - val_loss: 0.0664 - val_root_mean_squared_error: 0.2576
# Epoch 8/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0884 - root_mean_squared_error: 0.2974 - val_loss: 0.0554 - val_root_mean_squared_error: 0.2354
# Epoch 9/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0931 - root_mean_squared_error: 0.3051 - val_loss: 0.0372 - val_root_mean_squared_error: 0.1927
# Epoch 10/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0777 - root_mean_squared_error: 0.2787 - val_loss: 0.0264 - val_root_mean_squared_error: 0.1625
# Epoch 11/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0640 - root_mean_squared_error: 0.2530 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1466
# Epoch 12/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0489 - root_mean_squared_error: 0.2211 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1417
# Epoch 13/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0619 - root_mean_squared_error: 0.2487 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1366
# Epoch 14/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0488 - root_mean_squared_error: 0.2210 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1221
# Epoch 15/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0512 - root_mean_squared_error: 0.2263 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1197
# Epoch 16/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0437 - root_mean_squared_error: 0.2090 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1102
# Epoch 17/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0402 - root_mean_squared_error: 0.2005 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1010
# Epoch 18/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0425 - root_mean_squared_error: 0.2060 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0999
# Epoch 19/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0295 - root_mean_squared_error: 0.1719 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0971
# Epoch 20/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0304 - root_mean_squared_error: 0.1743 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0889
# Epoch 21/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0233 - root_mean_squared_error: 0.1528 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0881
# Epoch 22/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0227 - root_mean_squared_error: 0.1507 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0832
# Epoch 23/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0317 - root_mean_squared_error: 0.1781 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0764
# Epoch 24/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0285 - root_mean_squared_error: 0.1689 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0800
# Epoch 25/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0249 - root_mean_squared_error: 0.1577 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0739
# Epoch 1/25
# 21/21 [==============================] - 3s 33ms/step - loss: 0.3808 - root_mean_squared_error: 0.6171 - val_loss: 1.0747 - val_root_mean_squared_error: 1.0367
# Epoch 2/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1363 - root_mean_squared_error: 0.3691 - val_loss: 0.1792 - val_root_mean_squared_error: 0.4234
# Epoch 3/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1085 - root_mean_squared_error: 0.3294 - val_loss: 0.1303 - val_root_mean_squared_error: 0.3609
# Epoch 4/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0736 - root_mean_squared_error: 0.2713 - val_loss: 0.0750 - val_root_mean_squared_error: 0.2739
# Epoch 5/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0844 - root_mean_squared_error: 0.2905 - val_loss: 0.0350 - val_root_mean_squared_error: 0.1871
# Epoch 6/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0619 - root_mean_squared_error: 0.2487 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1403
# Epoch 7/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0634 - root_mean_squared_error: 0.2518 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1259
# Epoch 8/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0437 - root_mean_squared_error: 0.2091 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1220
# Epoch 9/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0530 - root_mean_squared_error: 0.2303 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1171
# Epoch 10/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0595 - root_mean_squared_error: 0.2440 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1278
# Epoch 11/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0521 - root_mean_squared_error: 0.2283 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1009
# Epoch 12/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0433 - root_mean_squared_error: 0.2081 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0983
# Epoch 13/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0329 - root_mean_squared_error: 0.1814 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1084
# Epoch 14/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0339 - root_mean_squared_error: 0.1842 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0975
# Epoch 15/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0312 - root_mean_squared_error: 0.1767 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1145
# Epoch 16/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0281 - root_mean_squared_error: 0.1677 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1058
# Epoch 17/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0260 - root_mean_squared_error: 0.1612 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0870
# Epoch 18/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0759
# Epoch 19/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0188 - root_mean_squared_error: 0.1372 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0762
# Epoch 20/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0222 - root_mean_squared_error: 0.1491 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0778
# Epoch 21/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0135 - root_mean_squared_error: 0.1163 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0770
# Epoch 22/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0151 - root_mean_squared_error: 0.1229 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0625
# Epoch 23/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0109 - root_mean_squared_error: 0.1045 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0647
# Epoch 24/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0107 - root_mean_squared_error: 0.1034 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0657
# Epoch 25/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0088 - root_mean_squared_error: 0.0939 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0583
# Epoch 1/25
# 21/21 [==============================] - 3s 30ms/step - loss: 0.2958 - root_mean_squared_error: 0.5439 - val_loss: 0.1137 - val_root_mean_squared_error: 0.3372
# Epoch 2/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0921 - root_mean_squared_error: 0.3035 - val_loss: 0.0635 - val_root_mean_squared_error: 0.2520
# Epoch 3/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0582 - root_mean_squared_error: 0.2412 - val_loss: 0.0484 - val_root_mean_squared_error: 0.2201
# Epoch 4/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0458 - root_mean_squared_error: 0.2140 - val_loss: 0.0376 - val_root_mean_squared_error: 0.1940
# Epoch 5/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0325 - root_mean_squared_error: 0.1804 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1459
# Epoch 6/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0262 - root_mean_squared_error: 0.1619 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1163
# Epoch 7/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0259 - root_mean_squared_error: 0.1610 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1039
# Epoch 8/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0214 - root_mean_squared_error: 0.1464 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0957
# Epoch 9/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0169 - root_mean_squared_error: 0.1302 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0965
# Epoch 10/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0151 - root_mean_squared_error: 0.1230 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0808
# Epoch 11/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0166 - root_mean_squared_error: 0.1287 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0731
# Epoch 12/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0721
# Epoch 13/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0131 - root_mean_squared_error: 0.1145 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0711
# Epoch 14/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0134 - root_mean_squared_error: 0.1156 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0694
# Epoch 15/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0118 - root_mean_squared_error: 0.1088 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0669
# Epoch 16/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0120 - root_mean_squared_error: 0.1093 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0663
# Epoch 17/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0130 - root_mean_squared_error: 0.1140 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0642
# Epoch 18/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0086 - root_mean_squared_error: 0.0925 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0641
# Epoch 19/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0071 - root_mean_squared_error: 0.0845 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0622
# Epoch 20/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0080 - root_mean_squared_error: 0.0896 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0622
# Epoch 21/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0619
# Epoch 22/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0070 - root_mean_squared_error: 0.0835 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0611
# Epoch 23/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0065 - root_mean_squared_error: 0.0808 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0594
# Epoch 24/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0062 - root_mean_squared_error: 0.0786 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0588
# Epoch 25/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0060 - root_mean_squared_error: 0.0772 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0577
# Epoch 1/25
# 21/21 [==============================] - 2s 28ms/step - loss: 0.4179 - root_mean_squared_error: 0.6464 - val_loss: 0.0626 - val_root_mean_squared_error: 0.2503
# Epoch 2/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1459 - root_mean_squared_error: 0.3819 - val_loss: 0.0575 - val_root_mean_squared_error: 0.2398
# Epoch 3/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0809 - root_mean_squared_error: 0.2844 - val_loss: 0.0574 - val_root_mean_squared_error: 0.2396
# Epoch 4/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0618 - root_mean_squared_error: 0.2486 - val_loss: 0.0517 - val_root_mean_squared_error: 0.2273
# Epoch 5/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0539 - root_mean_squared_error: 0.2321 - val_loss: 0.0510 - val_root_mean_squared_error: 0.2258
# Epoch 6/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0401 - root_mean_squared_error: 0.2002 - val_loss: 0.0267 - val_root_mean_squared_error: 0.1633
# Epoch 7/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0347 - root_mean_squared_error: 0.1862 - val_loss: 0.0322 - val_root_mean_squared_error: 0.1795
# Epoch 8/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0279 - root_mean_squared_error: 0.1670 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1449
# Epoch 9/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0257 - root_mean_squared_error: 0.1602 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1234
# Epoch 10/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0215 - root_mean_squared_error: 0.1467 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1211
# Epoch 11/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0203 - root_mean_squared_error: 0.1426 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1145
# Epoch 12/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0188 - root_mean_squared_error: 0.1371 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1034
# Epoch 13/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0147 - root_mean_squared_error: 0.1214 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0912
# Epoch 14/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0142 - root_mean_squared_error: 0.1191 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0896
# Epoch 15/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0873
# Epoch 16/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0139 - root_mean_squared_error: 0.1180 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0791
# Epoch 17/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0119 - root_mean_squared_error: 0.1093 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0719
# Epoch 18/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0101 - root_mean_squared_error: 0.1004 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0747
# Epoch 19/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0088 - root_mean_squared_error: 0.0939 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0706
# Epoch 20/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0093 - root_mean_squared_error: 0.0962 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0699
# Epoch 21/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0078 - root_mean_squared_error: 0.0886 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0715
# Epoch 22/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0074 - root_mean_squared_error: 0.0862 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0681
# Epoch 23/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0069 - root_mean_squared_error: 0.0832 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0672
# Epoch 24/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0069 - root_mean_squared_error: 0.0829 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0712
# Epoch 25/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0068 - root_mean_squared_error: 0.0823 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0644
# Epoch 1/25
# 21/21 [==============================] - 3s 26ms/step - loss: 0.8980 - root_mean_squared_error: 0.9476 - val_loss: 0.5430 - val_root_mean_squared_error: 0.7369
# Epoch 2/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4245 - root_mean_squared_error: 0.6516 - val_loss: 0.2524 - val_root_mean_squared_error: 0.5024
# Epoch 3/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2129 - root_mean_squared_error: 0.4614 - val_loss: 0.1588 - val_root_mean_squared_error: 0.3985
# Epoch 4/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.1064 - root_mean_squared_error: 0.3262 - val_loss: 0.0801 - val_root_mean_squared_error: 0.2830
# Epoch 5/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0601 - root_mean_squared_error: 0.2451 - val_loss: 0.0426 - val_root_mean_squared_error: 0.2063
# Epoch 6/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0416 - root_mean_squared_error: 0.2039 - val_loss: 0.0299 - val_root_mean_squared_error: 0.1730
# Epoch 7/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0307 - root_mean_squared_error: 0.1753 - val_loss: 0.0196 - val_root_mean_squared_error: 0.1399
# Epoch 8/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0217 - root_mean_squared_error: 0.1474 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1235
# Epoch 9/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0211 - root_mean_squared_error: 0.1453 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1150
# Epoch 10/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0183 - root_mean_squared_error: 0.1353 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1049
# Epoch 11/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0225 - root_mean_squared_error: 0.1501 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1042
# Epoch 12/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0151 - root_mean_squared_error: 0.1228 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1019
# Epoch 13/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0139 - root_mean_squared_error: 0.1180 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0955
# Epoch 14/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0133 - root_mean_squared_error: 0.1151 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0975
# Epoch 15/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0125 - root_mean_squared_error: 0.1116 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0908
# Epoch 16/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0120 - root_mean_squared_error: 0.1097 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0900
# Epoch 17/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0107 - root_mean_squared_error: 0.1035 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1002
# Epoch 18/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0124 - root_mean_squared_error: 0.1112 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0827
# Epoch 19/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0102 - root_mean_squared_error: 0.1008 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0802
# Epoch 20/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0104 - root_mean_squared_error: 0.1021 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0787
# Epoch 21/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0091 - root_mean_squared_error: 0.0951 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0905
# Epoch 22/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0093 - root_mean_squared_error: 0.0965 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0795
# Epoch 23/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0091 - root_mean_squared_error: 0.0955 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0755
# Epoch 24/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0087 - root_mean_squared_error: 0.0932 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0795
# Epoch 25/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0082 - root_mean_squared_error: 0.0903 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0792
# Epoch 1/25
# 21/21 [==============================] - 2s 30ms/step - loss: 0.2298 - root_mean_squared_error: 0.4794 - val_loss: 0.6078 - val_root_mean_squared_error: 0.7796
# Epoch 2/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0816 - root_mean_squared_error: 0.2857 - val_loss: 0.1963 - val_root_mean_squared_error: 0.4430
# Epoch 3/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0567 - root_mean_squared_error: 0.2382 - val_loss: 0.0981 - val_root_mean_squared_error: 0.3132
# Epoch 4/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0413 - root_mean_squared_error: 0.2033 - val_loss: 0.0437 - val_root_mean_squared_error: 0.2090
# Epoch 5/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0437 - root_mean_squared_error: 0.2091 - val_loss: 0.0319 - val_root_mean_squared_error: 0.1787
# Epoch 6/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0386 - root_mean_squared_error: 0.1964 - val_loss: 0.0231 - val_root_mean_squared_error: 0.1519
# Epoch 7/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0328 - root_mean_squared_error: 0.1811 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1232
# Epoch 8/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0258 - root_mean_squared_error: 0.1608 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1034
# Epoch 9/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0217 - root_mean_squared_error: 0.1472 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0943
# Epoch 10/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0199 - root_mean_squared_error: 0.1412 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0878
# Epoch 11/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0167 - root_mean_squared_error: 0.1294 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0835
# Epoch 12/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0175 - root_mean_squared_error: 0.1321 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0823
# Epoch 13/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0186 - root_mean_squared_error: 0.1362 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0848
# Epoch 14/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0760
# Epoch 15/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0147 - root_mean_squared_error: 0.1211 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0727
# Epoch 16/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0157 - root_mean_squared_error: 0.1253 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0749
# Epoch 17/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0094 - root_mean_squared_error: 0.0970 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0684
# Epoch 18/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0110 - root_mean_squared_error: 0.1050 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0660
# Epoch 19/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0104 - root_mean_squared_error: 0.1018 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0620
# Epoch 20/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0097 - root_mean_squared_error: 0.0985 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0583
# Epoch 21/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0082 - root_mean_squared_error: 0.0905 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0566
# Epoch 22/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0075 - root_mean_squared_error: 0.0865 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0536
# Epoch 23/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0069 - root_mean_squared_error: 0.0833 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0530
# Epoch 24/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0075 - root_mean_squared_error: 0.0866 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0520
# Epoch 25/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0064 - root_mean_squared_error: 0.0800 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0509
# Epoch 1/25
# 21/21 [==============================] - 2s 30ms/step - loss: 0.5404 - root_mean_squared_error: 0.7351 - val_loss: 0.0622 - val_root_mean_squared_error: 0.2494
# Epoch 2/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1848 - root_mean_squared_error: 0.4299 - val_loss: 0.0309 - val_root_mean_squared_error: 0.1757
# Epoch 3/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.1023 - root_mean_squared_error: 0.3199 - val_loss: 0.0294 - val_root_mean_squared_error: 0.1714
# Epoch 4/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0742 - root_mean_squared_error: 0.2724 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1527
# Epoch 5/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0642 - root_mean_squared_error: 0.2534 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1438
# Epoch 6/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0565 - root_mean_squared_error: 0.2377 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1268
# Epoch 7/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0453 - root_mean_squared_error: 0.2129 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1174
# Epoch 8/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0382 - root_mean_squared_error: 0.1955 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1112
# Epoch 9/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0363 - root_mean_squared_error: 0.1906 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0997
# Epoch 10/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0307 - root_mean_squared_error: 0.1751 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0910
# Epoch 11/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0276 - root_mean_squared_error: 0.1661 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0837
# Epoch 12/25
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0224 - root_mean_squared_error: 0.1495 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0754
# Epoch 13/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0213 - root_mean_squared_error: 0.1460 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0688
# Epoch 14/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0232 - root_mean_squared_error: 0.1523 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0654
# Epoch 15/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0187 - root_mean_squared_error: 0.1367 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0644
# Epoch 16/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0175 - root_mean_squared_error: 0.1321 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0617
# Epoch 17/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0166 - root_mean_squared_error: 0.1287 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0591
# Epoch 18/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0145 - root_mean_squared_error: 0.1205 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0568
# Epoch 19/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0132 - root_mean_squared_error: 0.1149 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0557
# Epoch 20/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0118 - root_mean_squared_error: 0.1087 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0544
# Epoch 21/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0123 - root_mean_squared_error: 0.1111 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0532
# Epoch 22/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0117 - root_mean_squared_error: 0.1081 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0520
# Epoch 23/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0099 - root_mean_squared_error: 0.0996 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0503
# Epoch 24/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0093 - root_mean_squared_error: 0.0967 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0489
# Epoch 25/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0094 - root_mean_squared_error: 0.0967 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0478
# Epoch 1/25
# 21/21 [==============================] - 4s 27ms/step - loss: 0.3599 - root_mean_squared_error: 0.5999 - val_loss: 0.3196 - val_root_mean_squared_error: 0.5654
# Epoch 2/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1726 - root_mean_squared_error: 0.4154 - val_loss: 0.1303 - val_root_mean_squared_error: 0.3610
# Epoch 3/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1544 - root_mean_squared_error: 0.3930 - val_loss: 0.0943 - val_root_mean_squared_error: 0.3071
# Epoch 4/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1108 - root_mean_squared_error: 0.3328 - val_loss: 0.0621 - val_root_mean_squared_error: 0.2493
# Epoch 5/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0831 - root_mean_squared_error: 0.2882 - val_loss: 0.0390 - val_root_mean_squared_error: 0.1974
# Epoch 6/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0745 - root_mean_squared_error: 0.2729 - val_loss: 0.0268 - val_root_mean_squared_error: 0.1636
# Epoch 7/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0736 - root_mean_squared_error: 0.2712 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1490
# Epoch 8/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0734 - root_mean_squared_error: 0.2709 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1231
# Epoch 9/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0425 - root_mean_squared_error: 0.2063 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1118
# Epoch 10/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0395 - root_mean_squared_error: 0.1987 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1165
# Epoch 11/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0439 - root_mean_squared_error: 0.2095 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1098
# Epoch 12/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0395 - root_mean_squared_error: 0.1988 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1013
# Epoch 13/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0379 - root_mean_squared_error: 0.1947 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0987
# Epoch 14/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0325 - root_mean_squared_error: 0.1803 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1029
# Epoch 15/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0279 - root_mean_squared_error: 0.1671 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0985
# Epoch 16/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0208 - root_mean_squared_error: 0.1442 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0896
# Epoch 17/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0232 - root_mean_squared_error: 0.1524 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0906
# Epoch 18/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0214 - root_mean_squared_error: 0.1462 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0810
# Epoch 19/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0248 - root_mean_squared_error: 0.1574 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0695
# Epoch 20/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0166 - root_mean_squared_error: 0.1287 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0719
# Epoch 21/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0164 - root_mean_squared_error: 0.1282 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0720
# Epoch 22/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0162 - root_mean_squared_error: 0.1271 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0660
# Epoch 23/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0153 - root_mean_squared_error: 0.1238 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0654
# Epoch 24/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0136 - root_mean_squared_error: 0.1167 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0657
# Epoch 25/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0140 - root_mean_squared_error: 0.1185 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0679
# Epoch 1/25
# 21/21 [==============================] - 3s 26ms/step - loss: 0.3133 - root_mean_squared_error: 0.5598 - val_loss: 0.2169 - val_root_mean_squared_error: 0.4657
# Epoch 2/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1092 - root_mean_squared_error: 0.3305 - val_loss: 0.0805 - val_root_mean_squared_error: 0.2837
# Epoch 3/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0609 - root_mean_squared_error: 0.2468 - val_loss: 0.0545 - val_root_mean_squared_error: 0.2334
# Epoch 4/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0454 - root_mean_squared_error: 0.2131 - val_loss: 0.0424 - val_root_mean_squared_error: 0.2059
# Epoch 5/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0379 - root_mean_squared_error: 0.1947 - val_loss: 0.0348 - val_root_mean_squared_error: 0.1866
# Epoch 6/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0315 - root_mean_squared_error: 0.1776 - val_loss: 0.0259 - val_root_mean_squared_error: 0.1609
# Epoch 7/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0234 - root_mean_squared_error: 0.1530 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1364
# Epoch 8/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0215 - root_mean_squared_error: 0.1467 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1163
# Epoch 9/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0185 - root_mean_squared_error: 0.1359 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1043
# Epoch 10/25
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0168 - root_mean_squared_error: 0.1297 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0964
# Epoch 11/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0153 - root_mean_squared_error: 0.1235 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0860
# Epoch 12/25
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0133 - root_mean_squared_error: 0.1155 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0778
# Epoch 13/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0094 - root_mean_squared_error: 0.0967 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0725
# Epoch 14/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0097 - root_mean_squared_error: 0.0984 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0685
# Epoch 15/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0094 - root_mean_squared_error: 0.0971 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0634
# Epoch 16/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0085 - root_mean_squared_error: 0.0920 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0606
# Epoch 17/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0086 - root_mean_squared_error: 0.0926 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0582
# Epoch 18/25
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0071 - root_mean_squared_error: 0.0844 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0562
# Epoch 19/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0070 - root_mean_squared_error: 0.0834 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0534
# Epoch 20/25
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0068 - root_mean_squared_error: 0.0825 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0524
# Epoch 21/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0056 - root_mean_squared_error: 0.0751 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0511
# Epoch 22/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0057 - root_mean_squared_error: 0.0757 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0507
# Epoch 23/25
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0047 - root_mean_squared_error: 0.0687 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0501
# Epoch 24/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0048 - root_mean_squared_error: 0.0694 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0490
# Epoch 25/25
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0051 - root_mean_squared_error: 0.0712 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0491

# %%
# summarize history for loss
plt.plot(model2.history['loss'])
plt.plot(model2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#Final model
# WModel save
callbacks = tf.keras.callbacks.ModelCheckpoint(filepath + "M2", save_best_only = True)
for train_index, val_index in kfold_generator.split(df_x, df_y):
    # Split training dataset.
    train_x, train_y = df_x.iloc[train_index], df_y.iloc[train_index]
    # Split validation dataset.
    val_x, val_y = df_x.iloc[val_index], df_y.iloc[val_index]
    # Make tensor dataset.
    ##tf_train = tf.data.Dataset.from_tensor_slices((train_x, train_y)).shuffle(2022).batch(500, drop_remainder=True).prefetch(1)
    ##tf_val = tf.data.Dataset.from_tensor_slices((val_x, val_y)).shuffle(2022).batch(1024, drop_remainder=True).prefetch(1)
    # Load model
    model = pythonash_model()
    # Model fitting
    
    model2 = model.fit(train_x, train_y, callbacks = callbacks, batch_size=64, epochs = 8, ### change the epochs into more numbers.
             validation_data = (val_x, val_y), shuffle=True)
    # Delete tensor dataset and model to save memory
    del model
    ##del tf_train
    ##del tf_val
    
best_model = tf.keras.models.load_model(filepath + "M2")   
pred2 = best_model.predict(test_x)
# Out:
# Epoch 1/8
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4914 - root_mean_squared_error: 0.7010 INFO:tensorflow:Assets written to: M2\assets
# 21/21 [==============================] - 6s 189ms/step - loss: 0.4783 - root_mean_squared_error: 0.6916 - val_loss: 0.2336 - val_root_mean_squared_error: 0.4833
# Epoch 2/8
# 20/21 [===========================>..] - ETA: 0s - loss: 0.1755 - root_mean_squared_error: 0.4189INFO:tensorflow:Assets written to: M2\assets
# 21/21 [==============================] - 3s 172ms/step - loss: 0.1732 - root_mean_squared_error: 0.4162 - val_loss: 0.1280 - val_root_mean_squared_error: 0.3577
# Epoch 3/8
# 14/21 [===================>..........] - ETA: 0s - loss: 0.1309 - root_mean_squared_error: 0.3618INFO:tensorflow:Assets written to: M2\assets
# 21/21 [==============================] - 3s 165ms/step - loss: 0.1045 - root_mean_squared_error: 0.3233 - val_loss: 0.0709 - val_root_mean_squared_error: 0.2662
# Epoch 4/8
# 18/21 [========================>.....] - ETA: 0s - loss: 0.0942 - root_mean_squared_error: 0.3069INFO:tensorflow:Assets written to: M2\assets
# 21/21 [==============================] - 4s 210ms/step - loss: 0.0865 - root_mean_squared_error: 0.2941 - val_loss: 0.0478 - val_root_mean_squared_error: 0.2187
# Epoch 5/8
# 18/21 [========================>.....] - ETA: 0s - loss: 0.0665 - root_mean_squared_error: 0.2579INFO:tensorflow:Assets written to: M2\assets
# 21/21 [==============================] - 3s 166ms/step - loss: 0.0687 - root_mean_squared_error: 0.2622 - val_loss: 0.0380 - val_root_mean_squared_error: 0.1950
# Epoch 6/8
# 15/21 [====================>.........] - ETA: 0s - loss: 0.0614 - root_mean_squared_error: 0.2477INFO:tensorflow:Assets written to: M2\assets
# 21/21 [==============================] - 3s 164ms/step - loss: 0.0605 - root_mean_squared_error: 0.2460 - val_loss: 0.0256 - val_root_mean_squared_error: 0.1601
# Epoch 7/8
# 14/21 [===================>..........] - ETA: 0s - loss: 0.0447 - root_mean_squared_error: 0.2113INFO:tensorflow:Assets written to: M2\assets
# 21/21 [==============================] - 4s 175ms/step - loss: 0.0557 - root_mean_squared_error: 0.2359 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1303
# Epoch 8/8
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0603 - root_mean_squared_error: 0.2455INFO:tensorflow:Assets written to: M2\assets
# 21/21 [==============================] - 3s 169ms/step - loss: 0.0624 - root_mean_squared_error: 0.2499 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1198
# Epoch 1/8
# 21/21 [==============================] - 2s 20ms/step - loss: 0.3857 - root_mean_squared_error: 0.6211 - val_loss: 0.1037 - val_root_mean_squared_error: 0.3220
# Epoch 2/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1333 - root_mean_squared_error: 0.3652 - val_loss: 0.0340 - val_root_mean_squared_error: 0.1843
# Epoch 3/8
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0909 - root_mean_squared_error: 0.3015 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1285
# Epoch 4/8
# 21/21 [==============================] - ETA: 0s - loss: 0.0890 - root_mean_squared_error: 0.2983INFO:tensorflow:Assets written to: M2\assets
# 21/21 [==============================] - 4s 221ms/step - loss: 0.0890 - root_mean_squared_error: 0.2983 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1175
# Epoch 5/8
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0754 - root_mean_squared_error: 0.2747INFO:tensorflow:Assets written to: M2\assets
# 21/21 [==============================] - 3s 167ms/step - loss: 0.0741 - root_mean_squared_error: 0.2722 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1006
# Epoch 6/8
# 21/21 [==============================] - ETA: 0s - loss: 0.0588 - root_mean_squared_error: 0.2424INFO:tensorflow:Assets written to: M2\assets
# 21/21 [==============================] - 4s 192ms/step - loss: 0.0588 - root_mean_squared_error: 0.2424 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0998
# Epoch 7/8
# 14/21 [===================>..........] - ETA: 0s - loss: 0.0380 - root_mean_squared_error: 0.1950INFO:tensorflow:Assets written to: M2\assets
# 21/21 [==============================] - 3s 173ms/step - loss: 0.0485 - root_mean_squared_error: 0.2203 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0956
# Epoch 8/8
# 18/21 [========================>.....] - ETA: 0s - loss: 0.0483 - root_mean_squared_error: 0.2199INFO:tensorflow:Assets written to: M2\assets
# 21/21 [==============================] - 4s 218ms/step - loss: 0.0483 - root_mean_squared_error: 0.2197 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0931
# Epoch 1/8
# 21/21 [==============================] - 2s 21ms/step - loss: 0.1911 - root_mean_squared_error: 0.4371 - val_loss: 0.3427 - val_root_mean_squared_error: 0.5854
# Epoch 2/8
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0724 - root_mean_squared_error: 0.2690 - val_loss: 0.1564 - val_root_mean_squared_error: 0.3955
# Epoch 3/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0539 - root_mean_squared_error: 0.2321 - val_loss: 0.0708 - val_root_mean_squared_error: 0.2661
# Epoch 4/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0437 - root_mean_squared_error: 0.2090 - val_loss: 0.0527 - val_root_mean_squared_error: 0.2296
# Epoch 5/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0362 - root_mean_squared_error: 0.1902 - val_loss: 0.0286 - val_root_mean_squared_error: 0.1692
# Epoch 6/8
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0267 - root_mean_squared_error: 0.1634 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1377
# Epoch 7/8
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0240 - root_mean_squared_error: 0.1548 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1076
# Epoch 8/8
# 15/21 [====================>.........] - ETA: 0s - loss: 0.0210 - root_mean_squared_error: 0.1450INFO:tensorflow:Assets written to: M2\assets
# 21/21 [==============================] - 3s 171ms/step - loss: 0.0204 - root_mean_squared_error: 0.1429 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0882
# Epoch 1/8
# 21/21 [==============================] - 2s 17ms/step - loss: 0.6945 - root_mean_squared_error: 0.8334 - val_loss: 0.3395 - val_root_mean_squared_error: 0.5827
# Epoch 2/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2479 - root_mean_squared_error: 0.4979 - val_loss: 0.4186 - val_root_mean_squared_error: 0.6470
# Epoch 3/8
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1091 - root_mean_squared_error: 0.3303 - val_loss: 0.1879 - val_root_mean_squared_error: 0.4335
# Epoch 4/8
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0753 - root_mean_squared_error: 0.2744 - val_loss: 0.1352 - val_root_mean_squared_error: 0.3677
# Epoch 5/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0552 - root_mean_squared_error: 0.2349 - val_loss: 0.0931 - val_root_mean_squared_error: 0.3051
# Epoch 6/8
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0469 - root_mean_squared_error: 0.2165 - val_loss: 0.0660 - val_root_mean_squared_error: 0.2570
# Epoch 7/8
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0404 - root_mean_squared_error: 0.2010 - val_loss: 0.0403 - val_root_mean_squared_error: 0.2008
# Epoch 8/8
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0395 - root_mean_squared_error: 0.1987 - val_loss: 0.0284 - val_root_mean_squared_error: 0.1686
# Epoch 1/8
# 21/21 [==============================] - 2s 18ms/step - loss: 0.6928 - root_mean_squared_error: 0.8324 - val_loss: 1.1893 - val_root_mean_squared_error: 1.0905
# Epoch 2/8
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2985 - root_mean_squared_error: 0.5463 - val_loss: 0.4757 - val_root_mean_squared_error: 0.6897
# Epoch 3/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1731 - root_mean_squared_error: 0.4161 - val_loss: 0.2604 - val_root_mean_squared_error: 0.5103
# Epoch 4/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1264 - root_mean_squared_error: 0.3556 - val_loss: 0.1345 - val_root_mean_squared_error: 0.3668
# Epoch 5/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1422 - root_mean_squared_error: 0.3771 - val_loss: 0.1028 - val_root_mean_squared_error: 0.3206
# Epoch 6/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0752 - root_mean_squared_error: 0.2742 - val_loss: 0.0704 - val_root_mean_squared_error: 0.2653
# Epoch 7/8
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0872 - root_mean_squared_error: 0.2953 - val_loss: 0.0324 - val_root_mean_squared_error: 0.1800
# Epoch 8/8
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0510 - root_mean_squared_error: 0.2257 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1548
# Epoch 1/8
# 21/21 [==============================] - 2s 16ms/step - loss: 0.7725 - root_mean_squared_error: 0.8789 - val_loss: 1.0553 - val_root_mean_squared_error: 1.0273
# Epoch 2/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2861 - root_mean_squared_error: 0.5349 - val_loss: 0.3901 - val_root_mean_squared_error: 0.6246
# Epoch 3/8
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1474 - root_mean_squared_error: 0.3839 - val_loss: 0.1041 - val_root_mean_squared_error: 0.3227
# Epoch 4/8
# 21/21 [==============================] - 0s 6ms/step - loss: 0.1060 - root_mean_squared_error: 0.3256 - val_loss: 0.0739 - val_root_mean_squared_error: 0.2719
# Epoch 5/8
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0759 - root_mean_squared_error: 0.2754 - val_loss: 0.0447 - val_root_mean_squared_error: 0.2114
# Epoch 6/8
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0781 - root_mean_squared_error: 0.2794 - val_loss: 0.0409 - val_root_mean_squared_error: 0.2022
# Epoch 7/8
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0556 - root_mean_squared_error: 0.2358 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1838
# Epoch 8/8
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0510 - root_mean_squared_error: 0.2259 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1543
# Epoch 1/8
# 21/21 [==============================] - 2s 18ms/step - loss: 0.8180 - root_mean_squared_error: 0.9044 - val_loss: 0.6245 - val_root_mean_squared_error: 0.7903
# Epoch 2/8
# 21/21 [==============================] - 0s 3ms/step - loss: 0.3367 - root_mean_squared_error: 0.5803 - val_loss: 0.4810 - val_root_mean_squared_error: 0.6935
# Epoch 3/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2145 - root_mean_squared_error: 0.4632 - val_loss: 0.3944 - val_root_mean_squared_error: 0.6280
# Epoch 4/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1886 - root_mean_squared_error: 0.4343 - val_loss: 0.1493 - val_root_mean_squared_error: 0.3864
# Epoch 5/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1858 - root_mean_squared_error: 0.4310 - val_loss: 0.0947 - val_root_mean_squared_error: 0.3077
# Epoch 6/8
# 21/21 [==============================] - 0s 6ms/step - loss: 0.1490 - root_mean_squared_error: 0.3860 - val_loss: 0.0502 - val_root_mean_squared_error: 0.2240
# Epoch 7/8
# 21/21 [==============================] - 0s 6ms/step - loss: 0.1469 - root_mean_squared_error: 0.3833 - val_loss: 0.0463 - val_root_mean_squared_error: 0.2151
# Epoch 8/8
# 21/21 [==============================] - 0s 6ms/step - loss: 0.1095 - root_mean_squared_error: 0.3309 - val_loss: 0.0287 - val_root_mean_squared_error: 0.1695
# Epoch 1/8
# 21/21 [==============================] - 2s 20ms/step - loss: 0.4002 - root_mean_squared_error: 0.6326 - val_loss: 0.1500 - val_root_mean_squared_error: 0.3873
# Epoch 2/8
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1702 - root_mean_squared_error: 0.4126 - val_loss: 0.2312 - val_root_mean_squared_error: 0.4808
# Epoch 3/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1447 - root_mean_squared_error: 0.3803 - val_loss: 0.1633 - val_root_mean_squared_error: 0.4041
# Epoch 4/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1044 - root_mean_squared_error: 0.3232 - val_loss: 0.1026 - val_root_mean_squared_error: 0.3204
# Epoch 5/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0921 - root_mean_squared_error: 0.3035 - val_loss: 0.0961 - val_root_mean_squared_error: 0.3100
# Epoch 6/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.1044 - root_mean_squared_error: 0.3231 - val_loss: 0.1307 - val_root_mean_squared_error: 0.3616
# Epoch 7/8
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0714 - root_mean_squared_error: 0.2671 - val_loss: 0.1162 - val_root_mean_squared_error: 0.3409
# Epoch 8/8
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0486 - root_mean_squared_error: 0.2206 - val_loss: 0.0850 - val_root_mean_squared_error: 0.2915
# Epoch 1/8
# 21/21 [==============================] - 2s 18ms/step - loss: 0.2129 - root_mean_squared_error: 0.4614 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1167
# Epoch 2/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0659 - root_mean_squared_error: 0.2568 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1557
# Epoch 3/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0374 - root_mean_squared_error: 0.1935 - val_loss: 0.0202 - val_root_mean_squared_error: 0.1422
# Epoch 4/8
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0277 - root_mean_squared_error: 0.1664 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1251
# Epoch 5/8
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0221 - root_mean_squared_error: 0.1488 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1158
# Epoch 6/8
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0188 - root_mean_squared_error: 0.1371 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1018
# Epoch 7/8
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0149 - root_mean_squared_error: 0.1219 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0887
# Epoch 8/8
# 16/21 [=====================>........] - ETA: 0s - loss: 0.0152 - root_mean_squared_error: 0.1233INFO:tensorflow:Assets written to: M2\assets
# 21/21 [==============================] - 3s 167ms/step - loss: 0.0150 - root_mean_squared_error: 0.1224 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0758
# Epoch 1/8
# 21/21 [==============================] - 3s 16ms/step - loss: 0.6399 - root_mean_squared_error: 0.8000 - val_loss: 0.2324 - val_root_mean_squared_error: 0.4821
# Epoch 2/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2308 - root_mean_squared_error: 0.4805 - val_loss: 0.1705 - val_root_mean_squared_error: 0.4129
# Epoch 3/8
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1214 - root_mean_squared_error: 0.3485 - val_loss: 0.1191 - val_root_mean_squared_error: 0.3451
# Epoch 4/8
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0895 - root_mean_squared_error: 0.2992 - val_loss: 0.0872 - val_root_mean_squared_error: 0.2953
# Epoch 5/8
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0754 - root_mean_squared_error: 0.2746 - val_loss: 0.1038 - val_root_mean_squared_error: 0.3222
# Epoch 6/8
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0737 - root_mean_squared_error: 0.2715 - val_loss: 0.1117 - val_root_mean_squared_error: 0.3342
# Epoch 7/8
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0553 - root_mean_squared_error: 0.2351 - val_loss: 0.0910 - val_root_mean_squared_error: 0.3016
# Epoch 8/8
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0565 - root_mean_squared_error: 0.2377 - val_loss: 0.0691 - val_root_mean_squared_error: 0.2629

# %%
figure(figsize=(20,8), dpi=80)

plt.plot(btc["1_Day_Price_Diff_Percent"][1500:1875].values, label = "Real")
plt.plot(pred2, label = "Pred")

plt.xlabel('Day')
# naming the y axis
plt.ylabel('Daily price difference in percent')
# giving a title to my graph
plt.title('Bitcoin price prediction with sentiment analysis')
  
# show a legend on the plot
plt.legend()
  
# function to show the plot
plt.show()
rmse_(btc["1_Day_Price_Diff_Percent"][1500:1875].values,pred2)
# Out:
# RMSE : 0.12088439132974417

# %%
plt.figure(figsize = (18,9))
plt.plot(range(df[1500:1875].shape[0]),df["_1_counts_diff_percent"][1500:1875])
plt.xticks(range(0,df[1500:1875].shape[0],500),df['Date'][1500:1875][1500:1875].loc[::500],rotation=45)
plt.xlabel('Date',fontsize=18)
plt.ylabel('Count',fontsize=18)
plt.title("Number of tweets per day")
plt.show()

# %%
plt.figure(figsize = (18,9))
plt.plot(range(df[1500:1875].shape[0]),df["score"][1500:1875])
plt.xticks(range(0,df[1500:1875].shape[0],500),df['Date'][1500:1875][1500:1875].loc[::500],rotation=45)
plt.xlabel('Date',fontsize=18)
plt.ylabel('Count',fontsize=18)
plt.title("Number of tweets per day")
plt.show()

# %%
figure(figsize=(20,8), dpi=80)

pred_price = []
for num1, num2 in zip(pred2, btc["Close"][1500:1875].values):
	pred_price.append((num1 * num2) + num2)

plt.plot(btc["1_Day_Price"][1500:1875].values, label = "Real")
plt.plot(pred_price, label = "Pred")

plt.xlabel('Day')
# naming the y axis
plt.ylabel('Price in Us Dollar')
# giving a title to my graph
plt.title('Bitcoin prediction')
  
# show a legend on the plot
plt.legend()
  
# function to show the plot
plt.show()
#rmse_(btc["1_Day_Price"][1500:1875].values,pred_price)

# %%
mixm1m2 = pred1 * 0.3 + pred2 * 0.7

figure(figsize=(20,8), dpi=80)

plt.plot(btc["1_Day_Price_Diff_Percent"][1500:1875].values, label = "Real")
plt.plot(mixm1m2, label = "Pred")

plt.xlabel('Day')
# naming the y axis
plt.ylabel('Daily price difference in percent')
# giving a title to my graph
plt.title('Bitcoin price prediction with sentiment analysis (mix)')
  
# show a legend on the plot
plt.legend()
  
# function to show the plot
plt.show()
rmse_(btc["1_Day_Price_Diff_Percent"][1500:1875].values,mixm1m2)
# Out:
# RMSE : 0.09062091853090998
